# %% [markdown]
# <h1><strong> <center>Classifying Outfit with Pytorch</center></strong></h1>

# %% [markdown]
# # 1. Introduction
#
# PyTorch is an open-source machine learning framework that allows developers to easily build and train neural networks.
# It was developed by Facebook's artificial intelligence research group and released in 2016.
# PyTorch is built on top of Python and provides two main features: a multi-dimensional tensor library and a dynamic computational graph.
#
# ![Pytorch.png](attachment:Pytorch.png)

# %% [markdown]
# Pytorch uses several modules to provide the ability of easily building and modifiying Neural Networks. Pytorch uses a data structure that is key for you to deeply understand it: the tensor.
#
# The tensor library in PyTorch provides a powerful array data structure that is similar to NumPy arrays, but with added support for GPUs. This makes PyTorch a popular choice for deep learning, where large amounts of data are processed in parallel on GPUs. As Numpy does, Pytorch includes a useful number of methods to manipulate tensors, such as reshaping, slicing, and concatenating.
#
# The dynamic computational graph in PyTorch is a unique feature that allows for more flexibility in building and training neural networks. Unlike static computational graphs, where the structure of the graph is determined before training begins, PyTorch allows for the graph to be modified dynamically during training. This means that developers can easily experiment with different network architectures and training strategies, without having to rewrite the entire network from scratch.
#
# In addition to its core features, PyTorch includes a number of useful libraries and tools for building and training neural networks. These include
# * <strong>TorchScript:</strong> allows developers to export PyTorch models to a format that can be run in other environments, such as C++ or mobile devices.
# * <strong>TorchVision:</strong> provides pre-trained models and datasets for computer vision tasks.
# * <strong>TorchVideo:</strong> a deep learning library for video understanding research
# * <strong>Lightning:</strong> the Deep Learning framework to train, deploy, and ship AI products Lightning fast.
# * <strong>TorchDrug:</strong> a powerful and flexible machine learning platform for drug discovery
# * <strong>Transformers:</strong> State-of-the-art Machine Learning architecture for Natural Language Processing
#
# Overall, PyTorch is a powerful and flexible machine learning framework that is widely used in both research and industry. Its ease of use, dynamic computational graph, and GPU support make it a popular choice for deep learning applications.

# %% [markdown]
# # 2. My First Machine Learning model

# %% [markdown]
# In this session, you won't code too much. Why? Because our purpose is you spend most of your time reading through the code included in this notebook.
# The notebook will run a complete Machine Learning model, we will walk through its building steps:
# * Load data from an external file
# * Preprocess data
# * Define the Machine Learning model architecture
# * Train the model
# * Test the model performance
# * Make your own predictions
#
# If you don't get some of the parts described here, don't worry!. We'll go back to them later in this course. Just run the code and enjoy watching how your computer learns and tries to build a better world!

# %% [markdown]
# # 3. Installing Pytorch

# %% [markdown]
# Please visit the following link: <a> https://pytorch.org/get-started/locally/ </a> to check out how to install Pytorch in your plattorm.
# If you use Microsoft Windows as your Operating System, just type the following command in your Conda environment
#
# conda install pytorch torchvision torchaudio pytorch-cuda=11.7 -c pytorch -c nvidia

# %% [markdown]
# Pytorch is a large package. It requires a while to install. Be patient!
# Don't forget to check if pytorch has been properly installed using the following command
#
# (my_conda_environment)$ conda list pytorch

# %% [markdown]
# # 4. Building the Machine Learning model

# %% [markdown]
# ## Importing modules
# Let's import the main libraries we're going to use in this project. We're going to take advantage of the modules that preprocess the data for us. We'll use the following Pytorch built-in modules:
# * Dataloader
# * Torchvision

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor

import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %% [markdown]
# ## Downloading datasets
#
# Every single Machine Learning model needs data to work. Data is usually divided in three parts:
# * <strong>Training dataset:</strong> is the portion of data the model uses to learn how it behaves. With this dataset, it learns patterns and how to predict
# * <strong>Validation dataset:</strong> a portion of the training dataset is used not to train the model, but to check if the model is learning properly. We call this portion validation dataset
# * <strong>Test dataset:</strong> after the model is trained, we take a portion of data and make the model run. We test if the model is predicting correctly. It's important to understand that this part of the dataset is never used to train the model!
#
# For the sake of simplicity, we'll start using a training dataset and a test dataset.

# %%
# Download training data from open datasets.
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# Download test data from open datasets.
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

# %% [markdown]
# It's key you understand how the dataset is built. Once you've gone through Numpy and Pandas crash course, you've got the right toolbox.
# Let's use them!

# %%
print(training_data)
# Out:
# Dataset FashionMNIST
#     Number of datapoints: 60000
#     Root location: data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()

# %% [markdown]
# <strong>Exercise 1: </strong>Figure out the data structure type of training_data

# %%
### Your code starts here ###

type(training_data)

### Your code ends here ###
# Out:
# torchvision.datasets.mnist.FashionMNIST

# %% [markdown]
# We are dealing with a weird type of data, it seems that the data is an FashionMNIST object: a customized object by Pytorch. Pytorch provides you some shortcuts to deal witht them as arrays

# %% [markdown]
# <strong>Exercise 2: </strong> Print the length of the dataset

# %%
### Your code starts here ###

dataset_length= len(training_data)

### Your code ends here ###

print("The length of the dataset is {0:d}".format(dataset_length))
# Out:
# The length of the dataset is 60000

# %% [markdown]
# Therefore, the function used for arrays works in the FashionMNIST object. Let's try to dig deeper in our dataset

# %% [markdown]
# <strong>Exercise 3: </strong> Extract the element in position 2501 a show the type of data you've extracted

# %%
### Your code starts here ###

data_type= type(training_data[2501])

### Your code ends here ###

print("The type of data you have extracted from FashionMinst is {0:s}".format(str(data_type)))
# Out:
# The type of data you have extracted from FashionMinst is <class 'tuple'>

# %% [markdown]
# So you now know the type of data every single element of the FashionMNIST dataset is. Let's check out what it keeps inside

# %% [markdown]
# <strong>Exercise 4: </strong> Check out the data type of the first element of the tuple and print it

# %%
### Your code starts here ###

type_first_element= type(training_data[0][0])

### Your code ends here ###

print("The first part of the tuple is a {0:s}".format(str(type_first_element)))
# Out:
# The first part of the tuple is a <class 'torch.Tensor'>

# %% [markdown]
# Ok now we are in front of our first Pytorch Tensor. Let's learn cool stuff about it

# %% [markdown]
# <strong>Exercise 5: </strong> Show the shape of the tensor

# %%
### Your code starts here ###

shape = training_data[0][0].shape

### Your code ends here ###

print("The shape of the Torch tensor is {0:s}".format(str(shape)))
# Out:
# The shape of the Torch tensor is torch.Size([1, 28, 28])

# %% [markdown]
# Ok we are dealing with a 3-dimensional matrix. It seems to be a grayscale picture. Let me explain why. In computers, colour pictures are represented with 3-dimensional matrices. This means that in general a picture is represented by three two-dimensional matrices that contain:
# * 1st matrix: the amount of red colour every single pixel of the picture has
# * 2nd matrix: the amount of green colour every single pixel of the picture has
# * 3rd matrix: the amount of blue colour every single pixel of the picture has
#
# The following picture shows the format explained above:
#
# ![picture_matrix.png](attachment:picture_matrix.png)
#
# Thus, the picture provided by Pytorch seems to be a normalized grayscale image (there is only one matrix in the first dimension, with values between 0 and 1) with 28x28 pixels of resolution.
#
# Now let's try to see what the picture contains. We're going to use the matplotlib module.

# %%
from matplotlib import pyplot as plt

# Uncomment next instruction to show the image 
first_part_tuple = training_data[0][0]

# %% [markdown]
# Uhm, it seems that matplotlib doen't understand what Pytorch gives as picture. Why? I'll give you the answer, matplotlib expects the picture. Maplotlib expects the three RGB matrices as the third dimension, MNIST library provides the three RGB matrices as the first dimension, let's reshape our matrix to fit matplotlib requirements

# %% [markdown]
# <strong>Exercise 5: </strong> Reshape the dimensions of your first_part_tuple variable to get [28,28,1] instead of [1,28,28]

# %%
### Your code starts here ###

permuted_picture = training_data[0][0].permute(1,2,0)

### Your code ends here ###

print ("The shape of the permuted image is now: {0:s}".format(str(permuted_picture.size())))
# Out:
# The shape of the permuted image is now: torch.Size([28, 28, 1])

# %% [markdown]
# Now maplotlib will be able to draw the picture, let's try it
#
# <strong>Exercise 6: </strong> Draw the picture represented in the variable permuted_picture

# %%
### Your code starts here ###


plt.imshow(permuted_picture,cmap="gray")

### Your code ends here ###

# %% [markdown]
# Ok now we can see what it looks like a dress! We know what the first element of the tuple contains. It contains a picture of a piece of clothe. But, what does the second part of the tuple represent? Let's check out the value the second part of the tuple contains

# %% [markdown]
# <strong>Exercise 7: </strong> Check the value of the second element of the 2500th tuple

# %%
### Your code starts here ###

second_value = training_data[0][1]

### Your code ends here ###

print("The second value of the tuple place in the 2500th position is {0:d}".format(second_value))
# Out:
# The second value of the tuple place in the 2500th position is 9

# %% [markdown]
# Therefore, we can conclude that FashionMNIST is a database of classified outfits.
#
# Now we know that the second part is what in Machine Learning is called the Label or Ground Truth. The label or ground truth is the information that the model uses to learn. The following list shows what every integer stands for:
#
# * 0 T-shirt/top
# * 1 Trouser
# * 2 Pullover
# * 3 Dress
# * 4 Coat
# * 5 Sandal
# * 6 Shirt
# * 7 Sneaker
# * 8 Bag
# * 9 Ankle boot

# %% [markdown]
# <strong>Exercise 8: </strong> Take a while to have a glance at different pictures and their label. Change the value of variable pic to see other outfits.

# %%
pic_num = 71

label_dict = {
    0 : 'T-shirt',
    1 : 'Trouser',
    2 : 'Pullover',
    3 : 'Dress',
    4 : 'Coat',
    5 : 'Sandal',
    6 : 'Shirt',
    7 : 'Sneaker',
    8 : 'Bag',
    9 : 'Ankel boot'
}

### Your code starts here ###

plt.imshow(training_data[pic_num][0].permute(1,2,0),cmap="gray")

### Your code ends here ###

print("The picture in the position number {0:d} is a {1:s}".format(pic_num,label_dict[training_data[pic_num][1]]))
# Out:
# The picture in the position number 71 is a Trouser

# %% [markdown]
# ## Structuring datasets

# %% [markdown]
# We are going to pass the Dataset as an argument to DataLoader. This wraps an iterable over our dataset, and supports automatic batching, sampling, shuffling and multiprocess data loading. Here we define a batch size of 64, i.e. each element in the dataloader iterable will return a batch of 64 features and labels.

# %%
batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break
# Out:
# Shape of X [N, C, H, W]: torch.Size([64, 1, 28, 28])
# Shape of y: torch.Size([64]) torch.int64

# %% [markdown]
# ## Creating the Machine Learning model

# %% [markdown]
# ### Enabling GPU hardware

# %% [markdown]
# Machine Learning foundations are based on Linear Algebra and number crunching with matrices. In order to make calculations with this huge amount of matrices, there exists specific hardware designed to speed this calculation up. This hardware is commonly called Graphics Processing Unit or <strong>GPU</strong>.
# Let's check if your computer has a GPU available for this project

# %%
# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
print("I have found {0:s} device".format(device))
# Out:
# I have found cpu device

# %% [markdown]
# As it's shown above, Pytorch includes a subclass named cuda in order to deal with GPU hardware. Let's figure out the name of the GPU your computer has installed.

# %%
if torch.cuda.is_available():
    print("There is a GPU available with the name {0:s}".format(torch.cuda.get_device_name(0)))
    torch.cuda.get_device_name(0)
else: print(f"There is no available GPU")
# Out:
# There is no available GPU

# %% [markdown]
# ### Define your first Neural Network
#
# All hands on deck! Your're ready to build your first neural network. First of all let's briefly describe what a Neural Network is:
#
# A neural network is a type of machine learning algorithm that is modeled after the structure and function of the human brain.
# It consists of a set of interconnected nodes or "neurons" organized into layers. Each neuron takes input from the neurons in the previous layer, performs a computation, and then passes its output to the next layer of neurons. Each neuron is composed of two parts:
# * <strong>A linear equation</strong>: it has the form y = w * x + b where:
#     * x is the input of the previous neuron
#     * w is the weight, the machine learning model will adjust the value of the weights in order to fit the model
#     * b is the bias, the machine learning model will adjust the value of the bias in order to fit the model
# * <strong>An activation function</strong>: tt determines whether the neuron should "fire" and transmit its output to the next layer of neurons or not. The activation function introduces non-linearities into the network, which enables it to learn complex patterns in the input data. There are many different types of activation functions, each with its own advantages and disadvantages, in this example we will use the RELU activation function

# %% [markdown]
# Depending on the number of layers, there are several types of neural networks, the following picture shows some of them:
#
# ![neural_types-3.png](attachment:neural_types-3.png)

# %% [markdown]
# The presence of an activation function differentiates the Logistic Regression from the Linear Regression. The presence of more than one hidden layer differentiates the Deep Neural Network from the Shallow Neural Network
#
# It's a good practice to draw a sketch of the network you want to implement. The sketch should show the dimensions of the input, and how the number of neurons changes throughout your architecture. Please have a glance at our proposal of neural network.
#
# ![architecture.png](attachment:architecture.png)

# %% [markdown]
# #### Build the architecture

# %%
# Define model
import torch.nn.functional as F


class MyNeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.Linear1 = nn.Linear(28*28,512)
        self.Linear2 = nn.Linear(512,512)
        self.Linear3 = nn.Linear(512,10)
    
    def forward(self, input):
        x = self.flatten(input)
        x = F.relu(self.Linear1(x))
        x = F.relu(self.Linear2(x)) 
        output = F.relu(self.Linear3(x)) 
        return output
    
    
model = MyNeuralNetwork().to(device)

# %% [markdown]
# We've defined our Neural Network, you can use the print instruction to check out some information of what you've created

# %%
print(model)
# Out:
# MyNeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (Linear1): Linear(in_features=784, out_features=512, bias=True)
#   (Linear2): Linear(in_features=512, out_features=512, bias=True)
#   (Linear3): Linear(in_features=512, out_features=10, bias=True)
# )

# %% [markdown]
# <strong>Exercise 9</strong>: Modify your neural network in order to include an additional hidden layer of 1024 neurons. Insert your new hidden layer between the current layer 2 and layer 3.

# %%
### Your code starts here ###
class MyNeuralNetwork2(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.Linear1 = nn.Linear(28*28,512)
        self.Linear2 = nn.Linear(512,512)
        self.Linear3 = nn.Linear(512,1024)
        self.Linear4 = nn.Linear(1024,10)
    
    def forward(self, input):
        x = self.flatten(input)
        x = F.relu(self.Linear1(x))
        x = F.relu(self.Linear2(x))
        x = F.relu(self.Linear3(x)) 
        output = F.relu(self.Linear4(x)) 
        return output
    
my_other_model = MyNeuralNetwork2().to(device)
### Your code ends here

print(my_other_model)
# Out:
# MyNeuralNetwork2(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (Linear1): Linear(in_features=784, out_features=512, bias=True)
#   (Linear2): Linear(in_features=512, out_features=512, bias=True)
#   (Linear3): Linear(in_features=512, out_features=1024, bias=True)
#   (Linear4): Linear(in_features=1024, out_features=10, bias=True)
# )

# %% [markdown]
# #### Define the loss Function
#
# The loss function is the method of evaluating how well your algorithm models the given data. If predictions of your model deviate too much from actual results, loss function would output a very large number. If your model is doing well, the loss function will output a low number.
#
# Gradually, with the help of the optimization function, loss function learns to reduce the error in prediction.
#
# Pytorch provides you with a complete toolbox with most used loss functions in Machine Learning. Please visit the following link for more information: <a> https://pytorch.org/docs/stable/nn.html#loss-functions </a>

# %% [markdown]
# <strong> Exercise 10: </strong> Set the Cross Entropy Loss function as the loss function for your experiment

# %%
### Your code starts here ###

loss_fn = nn.CrossEntropyLoss()

### Your code ends here ###

# %% [markdown]
# #### Define the Optimization Function
#
# Optimizers are algorithms or methods used to change the attributes of your neural network such as weights and bias in order to reduce the loss provided by the loss function.
#
# As in the loss function case, Pytorch provides a full set of optimization algorithms that fits your optimization requirements. Please have a look at the following link to learn more about optimization algorithms. <a> https://pytorch.org/docs/stable/optim.html </a>

# %% [markdown]
# <strong> Exercise 11: </strong> Set up the Stochastic Gradient Descent Algorithm with a learning rate = 1e-3

# %%
### Your code starts here ###

optimizer = torch.optim.SGD(my_other_model.parameters(),lr=1e-3)

### Your code ends here ###

# %% [markdown]
# #### Building the training loop
#
# Now we have all the tools to train our model. Training a model is an iterative process performed by a for loop. The training process is built with four bricks:
# * <strong>forward pass</strong>: in this step we plug in a batch of our training data and get the output. Then we compare the result of our model and the actual data.
# * <strong>backward pass</strong>: this step deals with the math neccesary to make the optimization work. We will dig into this step in the next code challenge
# * <strong>optimization</strong>: here we modify the weights and bias of our model in order to approach our results to the actual data and, therefore, minimize the loss
# * <strong>repetition</strong>: we repeat the algorithm as many times the number of epochs defines.

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)
        
        # Forward pass
        predicted = model(X)
        loss = loss_fn(predicted, y)

        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        
        # Optimization
        optimizer.step()
                
        # printing the loss every 100 epoc
        if batch % 100 == 0:
            loss, current = loss.item(), (batch + 1)
            print("Loss with batch nº {0:d}: {1:.6f}".format(current,loss))

# %% [markdown]
# Take a while to get how the train loop works, you will get better understanding if you print how the loop runs through the dataloader.

# %% [markdown]
# <strong>Exercise 12</strong>: Write down a loop to print the number of batch with the shape of every single train batch (X) and its label (y).

# %%
### Your code starts here ###
for i,batch in enumerate(train_dataloader):
    print(f"X {i}:\t{batch[0].shape}")
    print(f"Y {i}:\t{batch[1].shape}")   
### Your code ends here ###
# Out:
# X 0:	torch.Size([64, 1, 28, 28])
# Y 0:	torch.Size([64])
# X 1:	torch.Size([64, 1, 28, 28])
# Y 1:	torch.Size([64])
# X 2:	torch.Size([64, 1, 28, 28])
# Y 2:	torch.Size([64])
# X 3:	torch.Size([64, 1, 28, 28])
# Y 3:	torch.Size([64])
# X 4:	torch.Size([64, 1, 28, 28])
# Y 4:	torch.Size([64])
# X 5:	torch.Size([64, 1, 28, 28])
# Y 5:	torch.Size([64])
# X 6:	torch.Size([64, 1, 28, 28])
# Y 6:	torch.Size([64])
# X 7:	torch.Size([64, 1, 28, 28])
# Y 7:	torch.Size([64])
# X 8:	torch.Size([64, 1, 28, 28])
# Y 8:	torch.Size([64])
# X 9:	torch.Size([64, 1, 28, 28])
# Y 9:	torch.Size([64])
# X 10:	torch.Size([64, 1, 28, 28])
# Y 10:	torch.Size([64])
# X 11:	torch.Size([64, 1, 28, 28])
# Y 11:	torch.Size([64])
# X 12:	torch.Size([64, 1, 28, 28])
# Y 12:	torch.Size([64])
# X 13:	torch.Size([64, 1, 28, 28])
# Y 13:	torch.Size([64])
# X 14:	torch.Size([64, 1, 28, 28])
# Y 14:	torch.Size([64])
# X 15:	torch.Size([64, 1, 28, 28])
# Y 15:	torch.Size([64])
# X 16:	torch.Size([64, 1, 28, 28])
# Y 16:	torch.Size([64])
# X 17:	torch.Size([64, 1, 28, 28])
# Y 17:	torch.Size([64])
# X 18:	torch.Size([64, 1, 28, 28])
# Y 18:	torch.Size([64])
# X 19:	torch.Size([64, 1, 28, 28])
# Y 19:	torch.Size([64])
# X 20:	torch.Size([64, 1, 28, 28])
# Y 20:	torch.Size([64])
# X 21:	torch.Size([64, 1, 28, 28])
# Y 21:	torch.Size([64])
# X 22:	torch.Size([64, 1, 28, 28])
# Y 22:	torch.Size([64])
# X 23:	torch.Size([64, 1, 28, 28])
# Y 23:	torch.Size([64])
# X 24:	torch.Size([64, 1, 28, 28])
# Y 24:	torch.Size([64])
# X 25:	torch.Size([64, 1, 28, 28])
# Y 25:	torch.Size([64])
# X 26:	torch.Size([64, 1, 28, 28])
# Y 26:	torch.Size([64])
# X 27:	torch.Size([64, 1, 28, 28])
# Y 27:	torch.Size([64])
# X 28:	torch.Size([64, 1, 28, 28])
# Y 28:	torch.Size([64])
# X 29:	torch.Size([64, 1, 28, 28])
# Y 29:	torch.Size([64])
# X 30:	torch.Size([64, 1, 28, 28])
# Y 30:	torch.Size([64])
# X 31:	torch.Size([64, 1, 28, 28])
# Y 31:	torch.Size([64])
# X 32:	torch.Size([64, 1, 28, 28])
# Y 32:	torch.Size([64])
# X 33:	torch.Size([64, 1, 28, 28])
# Y 33:	torch.Size([64])
# X 34:	torch.Size([64, 1, 28, 28])
# Y 34:	torch.Size([64])
# X 35:	torch.Size([64, 1, 28, 28])
# Y 35:	torch.Size([64])
# X 36:	torch.Size([64, 1, 28, 28])
# Y 36:	torch.Size([64])
# X 37:	torch.Size([64, 1, 28, 28])
# Y 37:	torch.Size([64])
# X 38:	torch.Size([64, 1, 28, 28])
# Y 38:	torch.Size([64])
# X 39:	torch.Size([64, 1, 28, 28])
# Y 39:	torch.Size([64])
# X 40:	torch.Size([64, 1, 28, 28])
# Y 40:	torch.Size([64])
# X 41:	torch.Size([64, 1, 28, 28])
# Y 41:	torch.Size([64])
# X 42:	torch.Size([64, 1, 28, 28])
# Y 42:	torch.Size([64])
# X 43:	torch.Size([64, 1, 28, 28])
# Y 43:	torch.Size([64])
# X 44:	torch.Size([64, 1, 28, 28])
# Y 44:	torch.Size([64])
# X 45:	torch.Size([64, 1, 28, 28])
# Y 45:	torch.Size([64])
# X 46:	torch.Size([64, 1, 28, 28])
# Y 46:	torch.Size([64])
# X 47:	torch.Size([64, 1, 28, 28])
# Y 47:	torch.Size([64])
# X 48:	torch.Size([64, 1, 28, 28])
# Y 48:	torch.Size([64])
# X 49:	torch.Size([64, 1, 28, 28])
# Y 49:	torch.Size([64])
# X 50:	torch.Size([64, 1, 28, 28])
# Y 50:	torch.Size([64])
# X 51:	torch.Size([64, 1, 28, 28])
# Y 51:	torch.Size([64])
# X 52:	torch.Size([64, 1, 28, 28])
# Y 52:	torch.Size([64])
# X 53:	torch.Size([64, 1, 28, 28])
# Y 53:	torch.Size([64])
# X 54:	torch.Size([64, 1, 28, 28])
# Y 54:	torch.Size([64])
# X 55:	torch.Size([64, 1, 28, 28])
# Y 55:	torch.Size([64])
# X 56:	torch.Size([64, 1, 28, 28])
# Y 56:	torch.Size([64])
# X 57:	torch.Size([64, 1, 28, 28])
# Y 57:	torch.Size([64])
# X 58:	torch.Size([64, 1, 28, 28])
# Y 58:	torch.Size([64])
# X 59:	torch.Size([64, 1, 28, 28])
# Y 59:	torch.Size([64])
# X 60:	torch.Size([64, 1, 28, 28])
# Y 60:	torch.Size([64])
# X 61:	torch.Size([64, 1, 28, 28])
# Y 61:	torch.Size([64])
# X 62:	torch.Size([64, 1, 28, 28])
# Y 62:	torch.Size([64])
# X 63:	torch.Size([64, 1, 28, 28])
# Y 63:	torch.Size([64])
# X 64:	torch.Size([64, 1, 28, 28])
# Y 64:	torch.Size([64])
# X 65:	torch.Size([64, 1, 28, 28])
# Y 65:	torch.Size([64])
# X 66:	torch.Size([64, 1, 28, 28])
# Y 66:	torch.Size([64])
# X 67:	torch.Size([64, 1, 28, 28])
# Y 67:	torch.Size([64])
# X 68:	torch.Size([64, 1, 28, 28])
# Y 68:	torch.Size([64])
# X 69:	torch.Size([64, 1, 28, 28])
# Y 69:	torch.Size([64])
# X 70:	torch.Size([64, 1, 28, 28])
# Y 70:	torch.Size([64])
# X 71:	torch.Size([64, 1, 28, 28])
# Y 71:	torch.Size([64])
# X 72:	torch.Size([64, 1, 28, 28])
# Y 72:	torch.Size([64])
# X 73:	torch.Size([64, 1, 28, 28])
# Y 73:	torch.Size([64])
# X 74:	torch.Size([64, 1, 28, 28])
# Y 74:	torch.Size([64])
# X 75:	torch.Size([64, 1, 28, 28])
# Y 75:	torch.Size([64])
# X 76:	torch.Size([64, 1, 28, 28])
# Y 76:	torch.Size([64])
# X 77:	torch.Size([64, 1, 28, 28])
# Y 77:	torch.Size([64])
# X 78:	torch.Size([64, 1, 28, 28])
# Y 78:	torch.Size([64])
# X 79:	torch.Size([64, 1, 28, 28])
# Y 79:	torch.Size([64])
# X 80:	torch.Size([64, 1, 28, 28])
# Y 80:	torch.Size([64])
# X 81:	torch.Size([64, 1, 28, 28])
# Y 81:	torch.Size([64])
# X 82:	torch.Size([64, 1, 28, 28])
# Y 82:	torch.Size([64])
# X 83:	torch.Size([64, 1, 28, 28])
# Y 83:	torch.Size([64])
# X 84:	torch.Size([64, 1, 28, 28])
# Y 84:	torch.Size([64])
# X 85:	torch.Size([64, 1, 28, 28])
# Y 85:	torch.Size([64])
# X 86:	torch.Size([64, 1, 28, 28])
# Y 86:	torch.Size([64])
# X 87:	torch.Size([64, 1, 28, 28])
# Y 87:	torch.Size([64])
# X 88:	torch.Size([64, 1, 28, 28])
# Y 88:	torch.Size([64])
# X 89:	torch.Size([64, 1, 28, 28])
# Y 89:	torch.Size([64])
# X 90:	torch.Size([64, 1, 28, 28])
# Y 90:	torch.Size([64])
# X 91:	torch.Size([64, 1, 28, 28])
# Y 91:	torch.Size([64])
# X 92:	torch.Size([64, 1, 28, 28])
# Y 92:	torch.Size([64])
# X 93:	torch.Size([64, 1, 28, 28])
# Y 93:	torch.Size([64])
# X 94:	torch.Size([64, 1, 28, 28])
# Y 94:	torch.Size([64])
# X 95:	torch.Size([64, 1, 28, 28])
# Y 95:	torch.Size([64])
# X 96:	torch.Size([64, 1, 28, 28])
# Y 96:	torch.Size([64])
# X 97:	torch.Size([64, 1, 28, 28])
# Y 97:	torch.Size([64])
# X 98:	torch.Size([64, 1, 28, 28])
# Y 98:	torch.Size([64])
# X 99:	torch.Size([64, 1, 28, 28])
# Y 99:	torch.Size([64])
# X 100:	torch.Size([64, 1, 28, 28])
# Y 100:	torch.Size([64])
# X 101:	torch.Size([64, 1, 28, 28])
# Y 101:	torch.Size([64])
# X 102:	torch.Size([64, 1, 28, 28])
# Y 102:	torch.Size([64])
# X 103:	torch.Size([64, 1, 28, 28])
# Y 103:	torch.Size([64])
# X 104:	torch.Size([64, 1, 28, 28])
# Y 104:	torch.Size([64])
# X 105:	torch.Size([64, 1, 28, 28])
# Y 105:	torch.Size([64])
# X 106:	torch.Size([64, 1, 28, 28])
# Y 106:	torch.Size([64])
# X 107:	torch.Size([64, 1, 28, 28])
# Y 107:	torch.Size([64])
# X 108:	torch.Size([64, 1, 28, 28])
# Y 108:	torch.Size([64])
# X 109:	torch.Size([64, 1, 28, 28])
# Y 109:	torch.Size([64])
# X 110:	torch.Size([64, 1, 28, 28])
# Y 110:	torch.Size([64])
# X 111:	torch.Size([64, 1, 28, 28])
# Y 111:	torch.Size([64])
# X 112:	torch.Size([64, 1, 28, 28])
# Y 112:	torch.Size([64])
# X 113:	torch.Size([64, 1, 28, 28])
# Y 113:	torch.Size([64])
# X 114:	torch.Size([64, 1, 28, 28])
# Y 114:	torch.Size([64])
# X 115:	torch.Size([64, 1, 28, 28])
# Y 115:	torch.Size([64])
# X 116:	torch.Size([64, 1, 28, 28])
# Y 116:	torch.Size([64])
# X 117:	torch.Size([64, 1, 28, 28])
# Y 117:	torch.Size([64])
# X 118:	torch.Size([64, 1, 28, 28])
# Y 118:	torch.Size([64])
# X 119:	torch.Size([64, 1, 28, 28])
# Y 119:	torch.Size([64])
# X 120:	torch.Size([64, 1, 28, 28])
# Y 120:	torch.Size([64])
# X 121:	torch.Size([64, 1, 28, 28])
# Y 121:	torch.Size([64])
# X 122:	torch.Size([64, 1, 28, 28])
# Y 122:	torch.Size([64])
# X 123:	torch.Size([64, 1, 28, 28])
# Y 123:	torch.Size([64])
# X 124:	torch.Size([64, 1, 28, 28])
# Y 124:	torch.Size([64])
# X 125:	torch.Size([64, 1, 28, 28])
# Y 125:	torch.Size([64])
# X 126:	torch.Size([64, 1, 28, 28])
# Y 126:	torch.Size([64])
# X 127:	torch.Size([64, 1, 28, 28])
# Y 127:	torch.Size([64])
# X 128:	torch.Size([64, 1, 28, 28])
# Y 128:	torch.Size([64])
# X 129:	torch.Size([64, 1, 28, 28])
# Y 129:	torch.Size([64])
# X 130:	torch.Size([64, 1, 28, 28])
# Y 130:	torch.Size([64])
# X 131:	torch.Size([64, 1, 28, 28])
# Y 131:	torch.Size([64])
# X 132:	torch.Size([64, 1, 28, 28])
# Y 132:	torch.Size([64])
# X 133:	torch.Size([64, 1, 28, 28])
# Y 133:	torch.Size([64])
# X 134:	torch.Size([64, 1, 28, 28])
# Y 134:	torch.Size([64])
# X 135:	torch.Size([64, 1, 28, 28])
# Y 135:	torch.Size([64])
# X 136:	torch.Size([64, 1, 28, 28])
# Y 136:	torch.Size([64])
# X 137:	torch.Size([64, 1, 28, 28])
# Y 137:	torch.Size([64])
# X 138:	torch.Size([64, 1, 28, 28])
# Y 138:	torch.Size([64])
# X 139:	torch.Size([64, 1, 28, 28])
# Y 139:	torch.Size([64])
# X 140:	torch.Size([64, 1, 28, 28])
# Y 140:	torch.Size([64])
# X 141:	torch.Size([64, 1, 28, 28])
# Y 141:	torch.Size([64])
# X 142:	torch.Size([64, 1, 28, 28])
# Y 142:	torch.Size([64])
# X 143:	torch.Size([64, 1, 28, 28])
# Y 143:	torch.Size([64])
# X 144:	torch.Size([64, 1, 28, 28])
# Y 144:	torch.Size([64])
# X 145:	torch.Size([64, 1, 28, 28])
# Y 145:	torch.Size([64])
# X 146:	torch.Size([64, 1, 28, 28])
# Y 146:	torch.Size([64])
# X 147:	torch.Size([64, 1, 28, 28])
# Y 147:	torch.Size([64])
# X 148:	torch.Size([64, 1, 28, 28])
# Y 148:	torch.Size([64])
# X 149:	torch.Size([64, 1, 28, 28])
# Y 149:	torch.Size([64])
# X 150:	torch.Size([64, 1, 28, 28])
# Y 150:	torch.Size([64])
# X 151:	torch.Size([64, 1, 28, 28])
# Y 151:	torch.Size([64])
# X 152:	torch.Size([64, 1, 28, 28])
# Y 152:	torch.Size([64])
# X 153:	torch.Size([64, 1, 28, 28])
# Y 153:	torch.Size([64])
# X 154:	torch.Size([64, 1, 28, 28])
# Y 154:	torch.Size([64])
# X 155:	torch.Size([64, 1, 28, 28])
# Y 155:	torch.Size([64])
# X 156:	torch.Size([64, 1, 28, 28])
# Y 156:	torch.Size([64])
# X 157:	torch.Size([64, 1, 28, 28])
# Y 157:	torch.Size([64])
# X 158:	torch.Size([64, 1, 28, 28])
# Y 158:	torch.Size([64])
# X 159:	torch.Size([64, 1, 28, 28])
# Y 159:	torch.Size([64])
# X 160:	torch.Size([64, 1, 28, 28])
# Y 160:	torch.Size([64])
# X 161:	torch.Size([64, 1, 28, 28])
# Y 161:	torch.Size([64])
# X 162:	torch.Size([64, 1, 28, 28])
# Y 162:	torch.Size([64])
# X 163:	torch.Size([64, 1, 28, 28])
# Y 163:	torch.Size([64])
# X 164:	torch.Size([64, 1, 28, 28])
# Y 164:	torch.Size([64])
# X 165:	torch.Size([64, 1, 28, 28])
# Y 165:	torch.Size([64])
# X 166:	torch.Size([64, 1, 28, 28])
# Y 166:	torch.Size([64])
# X 167:	torch.Size([64, 1, 28, 28])
# Y 167:	torch.Size([64])
# X 168:	torch.Size([64, 1, 28, 28])
# Y 168:	torch.Size([64])
# X 169:	torch.Size([64, 1, 28, 28])
# Y 169:	torch.Size([64])
# X 170:	torch.Size([64, 1, 28, 28])
# Y 170:	torch.Size([64])
# X 171:	torch.Size([64, 1, 28, 28])
# Y 171:	torch.Size([64])
# X 172:	torch.Size([64, 1, 28, 28])
# Y 172:	torch.Size([64])
# X 173:	torch.Size([64, 1, 28, 28])
# Y 173:	torch.Size([64])
# X 174:	torch.Size([64, 1, 28, 28])
# Y 174:	torch.Size([64])
# X 175:	torch.Size([64, 1, 28, 28])
# Y 175:	torch.Size([64])
# X 176:	torch.Size([64, 1, 28, 28])
# Y 176:	torch.Size([64])
# X 177:	torch.Size([64, 1, 28, 28])
# Y 177:	torch.Size([64])
# X 178:	torch.Size([64, 1, 28, 28])
# Y 178:	torch.Size([64])
# X 179:	torch.Size([64, 1, 28, 28])
# Y 179:	torch.Size([64])
# X 180:	torch.Size([64, 1, 28, 28])
# Y 180:	torch.Size([64])
# X 181:	torch.Size([64, 1, 28, 28])
# Y 181:	torch.Size([64])
# X 182:	torch.Size([64, 1, 28, 28])
# Y 182:	torch.Size([64])
# X 183:	torch.Size([64, 1, 28, 28])
# Y 183:	torch.Size([64])
# X 184:	torch.Size([64, 1, 28, 28])
# Y 184:	torch.Size([64])
# X 185:	torch.Size([64, 1, 28, 28])
# Y 185:	torch.Size([64])
# X 186:	torch.Size([64, 1, 28, 28])
# Y 186:	torch.Size([64])
# X 187:	torch.Size([64, 1, 28, 28])
# Y 187:	torch.Size([64])
# X 188:	torch.Size([64, 1, 28, 28])
# Y 188:	torch.Size([64])
# X 189:	torch.Size([64, 1, 28, 28])
# Y 189:	torch.Size([64])
# X 190:	torch.Size([64, 1, 28, 28])
# Y 190:	torch.Size([64])
# X 191:	torch.Size([64, 1, 28, 28])
# Y 191:	torch.Size([64])
# X 192:	torch.Size([64, 1, 28, 28])
# Y 192:	torch.Size([64])
# X 193:	torch.Size([64, 1, 28, 28])
# Y 193:	torch.Size([64])
# X 194:	torch.Size([64, 1, 28, 28])
# Y 194:	torch.Size([64])
# X 195:	torch.Size([64, 1, 28, 28])
# Y 195:	torch.Size([64])
# X 196:	torch.Size([64, 1, 28, 28])
# Y 196:	torch.Size([64])
# X 197:	torch.Size([64, 1, 28, 28])
# Y 197:	torch.Size([64])
# X 198:	torch.Size([64, 1, 28, 28])
# Y 198:	torch.Size([64])
# X 199:	torch.Size([64, 1, 28, 28])
# Y 199:	torch.Size([64])
# X 200:	torch.Size([64, 1, 28, 28])
# Y 200:	torch.Size([64])
# X 201:	torch.Size([64, 1, 28, 28])
# Y 201:	torch.Size([64])
# X 202:	torch.Size([64, 1, 28, 28])
# Y 202:	torch.Size([64])
# X 203:	torch.Size([64, 1, 28, 28])
# Y 203:	torch.Size([64])
# X 204:	torch.Size([64, 1, 28, 28])
# Y 204:	torch.Size([64])
# X 205:	torch.Size([64, 1, 28, 28])
# Y 205:	torch.Size([64])
# X 206:	torch.Size([64, 1, 28, 28])
# Y 206:	torch.Size([64])
# X 207:	torch.Size([64, 1, 28, 28])
# Y 207:	torch.Size([64])
# X 208:	torch.Size([64, 1, 28, 28])
# Y 208:	torch.Size([64])
# X 209:	torch.Size([64, 1, 28, 28])
# Y 209:	torch.Size([64])
# X 210:	torch.Size([64, 1, 28, 28])
# Y 210:	torch.Size([64])
# X 211:	torch.Size([64, 1, 28, 28])
# Y 211:	torch.Size([64])
# X 212:	torch.Size([64, 1, 28, 28])
# Y 212:	torch.Size([64])
# X 213:	torch.Size([64, 1, 28, 28])
# Y 213:	torch.Size([64])
# X 214:	torch.Size([64, 1, 28, 28])
# Y 214:	torch.Size([64])
# X 215:	torch.Size([64, 1, 28, 28])
# Y 215:	torch.Size([64])
# X 216:	torch.Size([64, 1, 28, 28])
# Y 216:	torch.Size([64])
# X 217:	torch.Size([64, 1, 28, 28])
# Y 217:	torch.Size([64])
# X 218:	torch.Size([64, 1, 28, 28])
# Y 218:	torch.Size([64])
# X 219:	torch.Size([64, 1, 28, 28])
# Y 219:	torch.Size([64])
# X 220:	torch.Size([64, 1, 28, 28])
# Y 220:	torch.Size([64])
# X 221:	torch.Size([64, 1, 28, 28])
# Y 221:	torch.Size([64])
# X 222:	torch.Size([64, 1, 28, 28])
# Y 222:	torch.Size([64])
# X 223:	torch.Size([64, 1, 28, 28])
# Y 223:	torch.Size([64])
# X 224:	torch.Size([64, 1, 28, 28])
# Y 224:	torch.Size([64])
# X 225:	torch.Size([64, 1, 28, 28])
# Y 225:	torch.Size([64])
# X 226:	torch.Size([64, 1, 28, 28])
# Y 226:	torch.Size([64])
# X 227:	torch.Size([64, 1, 28, 28])
# Y 227:	torch.Size([64])
# X 228:	torch.Size([64, 1, 28, 28])
# Y 228:	torch.Size([64])
# X 229:	torch.Size([64, 1, 28, 28])
# Y 229:	torch.Size([64])
# X 230:	torch.Size([64, 1, 28, 28])
# Y 230:	torch.Size([64])
# X 231:	torch.Size([64, 1, 28, 28])
# Y 231:	torch.Size([64])
# X 232:	torch.Size([64, 1, 28, 28])
# Y 232:	torch.Size([64])
# X 233:	torch.Size([64, 1, 28, 28])
# Y 233:	torch.Size([64])
# X 234:	torch.Size([64, 1, 28, 28])
# Y 234:	torch.Size([64])
# X 235:	torch.Size([64, 1, 28, 28])
# Y 235:	torch.Size([64])
# X 236:	torch.Size([64, 1, 28, 28])
# Y 236:	torch.Size([64])
# X 237:	torch.Size([64, 1, 28, 28])
# Y 237:	torch.Size([64])
# X 238:	torch.Size([64, 1, 28, 28])
# Y 238:	torch.Size([64])
# X 239:	torch.Size([64, 1, 28, 28])
# Y 239:	torch.Size([64])
# X 240:	torch.Size([64, 1, 28, 28])
# Y 240:	torch.Size([64])
# X 241:	torch.Size([64, 1, 28, 28])
# Y 241:	torch.Size([64])
# X 242:	torch.Size([64, 1, 28, 28])
# Y 242:	torch.Size([64])
# X 243:	torch.Size([64, 1, 28, 28])
# Y 243:	torch.Size([64])
# X 244:	torch.Size([64, 1, 28, 28])
# Y 244:	torch.Size([64])
# X 245:	torch.Size([64, 1, 28, 28])
# Y 245:	torch.Size([64])
# X 246:	torch.Size([64, 1, 28, 28])
# Y 246:	torch.Size([64])
# X 247:	torch.Size([64, 1, 28, 28])
# Y 247:	torch.Size([64])
# X 248:	torch.Size([64, 1, 28, 28])
# Y 248:	torch.Size([64])
# X 249:	torch.Size([64, 1, 28, 28])
# Y 249:	torch.Size([64])
# X 250:	torch.Size([64, 1, 28, 28])
# Y 250:	torch.Size([64])
# X 251:	torch.Size([64, 1, 28, 28])
# Y 251:	torch.Size([64])
# X 252:	torch.Size([64, 1, 28, 28])
# Y 252:	torch.Size([64])
# X 253:	torch.Size([64, 1, 28, 28])
# Y 253:	torch.Size([64])
# X 254:	torch.Size([64, 1, 28, 28])
# Y 254:	torch.Size([64])
# X 255:	torch.Size([64, 1, 28, 28])
# Y 255:	torch.Size([64])
# X 256:	torch.Size([64, 1, 28, 28])
# Y 256:	torch.Size([64])
# X 257:	torch.Size([64, 1, 28, 28])
# Y 257:	torch.Size([64])
# X 258:	torch.Size([64, 1, 28, 28])
# Y 258:	torch.Size([64])
# X 259:	torch.Size([64, 1, 28, 28])
# Y 259:	torch.Size([64])
# X 260:	torch.Size([64, 1, 28, 28])
# Y 260:	torch.Size([64])
# X 261:	torch.Size([64, 1, 28, 28])
# Y 261:	torch.Size([64])
# X 262:	torch.Size([64, 1, 28, 28])
# Y 262:	torch.Size([64])
# X 263:	torch.Size([64, 1, 28, 28])
# Y 263:	torch.Size([64])
# X 264:	torch.Size([64, 1, 28, 28])
# Y 264:	torch.Size([64])
# X 265:	torch.Size([64, 1, 28, 28])
# Y 265:	torch.Size([64])
# X 266:	torch.Size([64, 1, 28, 28])
# Y 266:	torch.Size([64])
# X 267:	torch.Size([64, 1, 28, 28])
# Y 267:	torch.Size([64])
# X 268:	torch.Size([64, 1, 28, 28])
# Y 268:	torch.Size([64])
# X 269:	torch.Size([64, 1, 28, 28])
# Y 269:	torch.Size([64])
# X 270:	torch.Size([64, 1, 28, 28])
# Y 270:	torch.Size([64])
# X 271:	torch.Size([64, 1, 28, 28])
# Y 271:	torch.Size([64])
# X 272:	torch.Size([64, 1, 28, 28])
# Y 272:	torch.Size([64])
# X 273:	torch.Size([64, 1, 28, 28])
# Y 273:	torch.Size([64])
# X 274:	torch.Size([64, 1, 28, 28])
# Y 274:	torch.Size([64])
# X 275:	torch.Size([64, 1, 28, 28])
# Y 275:	torch.Size([64])
# X 276:	torch.Size([64, 1, 28, 28])
# Y 276:	torch.Size([64])
# X 277:	torch.Size([64, 1, 28, 28])
# Y 277:	torch.Size([64])
# X 278:	torch.Size([64, 1, 28, 28])
# Y 278:	torch.Size([64])
# X 279:	torch.Size([64, 1, 28, 28])
# Y 279:	torch.Size([64])
# X 280:	torch.Size([64, 1, 28, 28])
# Y 280:	torch.Size([64])
# X 281:	torch.Size([64, 1, 28, 28])
# Y 281:	torch.Size([64])
# X 282:	torch.Size([64, 1, 28, 28])
# Y 282:	torch.Size([64])
# X 283:	torch.Size([64, 1, 28, 28])
# Y 283:	torch.Size([64])
# X 284:	torch.Size([64, 1, 28, 28])
# Y 284:	torch.Size([64])
# X 285:	torch.Size([64, 1, 28, 28])
# Y 285:	torch.Size([64])
# X 286:	torch.Size([64, 1, 28, 28])
# Y 286:	torch.Size([64])
# X 287:	torch.Size([64, 1, 28, 28])
# Y 287:	torch.Size([64])
# X 288:	torch.Size([64, 1, 28, 28])
# Y 288:	torch.Size([64])
# X 289:	torch.Size([64, 1, 28, 28])
# Y 289:	torch.Size([64])
# X 290:	torch.Size([64, 1, 28, 28])
# Y 290:	torch.Size([64])
# X 291:	torch.Size([64, 1, 28, 28])
# Y 291:	torch.Size([64])
# X 292:	torch.Size([64, 1, 28, 28])
# Y 292:	torch.Size([64])
# X 293:	torch.Size([64, 1, 28, 28])
# Y 293:	torch.Size([64])
# X 294:	torch.Size([64, 1, 28, 28])
# Y 294:	torch.Size([64])
# X 295:	torch.Size([64, 1, 28, 28])
# Y 295:	torch.Size([64])
# X 296:	torch.Size([64, 1, 28, 28])
# Y 296:	torch.Size([64])
# X 297:	torch.Size([64, 1, 28, 28])
# Y 297:	torch.Size([64])
# X 298:	torch.Size([64, 1, 28, 28])
# Y 298:	torch.Size([64])
# X 299:	torch.Size([64, 1, 28, 28])
# Y 299:	torch.Size([64])
# X 300:	torch.Size([64, 1, 28, 28])
# Y 300:	torch.Size([64])
# X 301:	torch.Size([64, 1, 28, 28])
# Y 301:	torch.Size([64])
# X 302:	torch.Size([64, 1, 28, 28])
# Y 302:	torch.Size([64])
# X 303:	torch.Size([64, 1, 28, 28])
# Y 303:	torch.Size([64])
# X 304:	torch.Size([64, 1, 28, 28])
# Y 304:	torch.Size([64])
# X 305:	torch.Size([64, 1, 28, 28])
# Y 305:	torch.Size([64])
# X 306:	torch.Size([64, 1, 28, 28])
# Y 306:	torch.Size([64])
# X 307:	torch.Size([64, 1, 28, 28])
# Y 307:	torch.Size([64])
# X 308:	torch.Size([64, 1, 28, 28])
# Y 308:	torch.Size([64])
# X 309:	torch.Size([64, 1, 28, 28])
# Y 309:	torch.Size([64])
# X 310:	torch.Size([64, 1, 28, 28])
# Y 310:	torch.Size([64])
# X 311:	torch.Size([64, 1, 28, 28])
# Y 311:	torch.Size([64])
# X 312:	torch.Size([64, 1, 28, 28])
# Y 312:	torch.Size([64])
# X 313:	torch.Size([64, 1, 28, 28])
# Y 313:	torch.Size([64])
# X 314:	torch.Size([64, 1, 28, 28])
# Y 314:	torch.Size([64])
# X 315:	torch.Size([64, 1, 28, 28])
# Y 315:	torch.Size([64])
# X 316:	torch.Size([64, 1, 28, 28])
# Y 316:	torch.Size([64])
# X 317:	torch.Size([64, 1, 28, 28])
# Y 317:	torch.Size([64])
# X 318:	torch.Size([64, 1, 28, 28])
# Y 318:	torch.Size([64])
# X 319:	torch.Size([64, 1, 28, 28])
# Y 319:	torch.Size([64])
# X 320:	torch.Size([64, 1, 28, 28])
# Y 320:	torch.Size([64])
# X 321:	torch.Size([64, 1, 28, 28])
# Y 321:	torch.Size([64])
# X 322:	torch.Size([64, 1, 28, 28])
# Y 322:	torch.Size([64])
# X 323:	torch.Size([64, 1, 28, 28])
# Y 323:	torch.Size([64])
# X 324:	torch.Size([64, 1, 28, 28])
# Y 324:	torch.Size([64])
# X 325:	torch.Size([64, 1, 28, 28])
# Y 325:	torch.Size([64])
# X 326:	torch.Size([64, 1, 28, 28])
# Y 326:	torch.Size([64])
# X 327:	torch.Size([64, 1, 28, 28])
# Y 327:	torch.Size([64])
# X 328:	torch.Size([64, 1, 28, 28])
# Y 328:	torch.Size([64])
# X 329:	torch.Size([64, 1, 28, 28])
# Y 329:	torch.Size([64])
# X 330:	torch.Size([64, 1, 28, 28])
# Y 330:	torch.Size([64])
# X 331:	torch.Size([64, 1, 28, 28])
# Y 331:	torch.Size([64])
# X 332:	torch.Size([64, 1, 28, 28])
# Y 332:	torch.Size([64])
# X 333:	torch.Size([64, 1, 28, 28])
# Y 333:	torch.Size([64])
# X 334:	torch.Size([64, 1, 28, 28])
# Y 334:	torch.Size([64])
# X 335:	torch.Size([64, 1, 28, 28])
# Y 335:	torch.Size([64])
# X 336:	torch.Size([64, 1, 28, 28])
# Y 336:	torch.Size([64])
# X 337:	torch.Size([64, 1, 28, 28])
# Y 337:	torch.Size([64])
# X 338:	torch.Size([64, 1, 28, 28])
# Y 338:	torch.Size([64])
# X 339:	torch.Size([64, 1, 28, 28])
# Y 339:	torch.Size([64])
# X 340:	torch.Size([64, 1, 28, 28])
# Y 340:	torch.Size([64])
# X 341:	torch.Size([64, 1, 28, 28])
# Y 341:	torch.Size([64])
# X 342:	torch.Size([64, 1, 28, 28])
# Y 342:	torch.Size([64])
# X 343:	torch.Size([64, 1, 28, 28])
# Y 343:	torch.Size([64])
# X 344:	torch.Size([64, 1, 28, 28])
# Y 344:	torch.Size([64])
# X 345:	torch.Size([64, 1, 28, 28])
# Y 345:	torch.Size([64])
# X 346:	torch.Size([64, 1, 28, 28])
# Y 346:	torch.Size([64])
# X 347:	torch.Size([64, 1, 28, 28])
# Y 347:	torch.Size([64])
# X 348:	torch.Size([64, 1, 28, 28])
# Y 348:	torch.Size([64])
# X 349:	torch.Size([64, 1, 28, 28])
# Y 349:	torch.Size([64])
# X 350:	torch.Size([64, 1, 28, 28])
# Y 350:	torch.Size([64])
# X 351:	torch.Size([64, 1, 28, 28])
# Y 351:	torch.Size([64])
# X 352:	torch.Size([64, 1, 28, 28])
# Y 352:	torch.Size([64])
# X 353:	torch.Size([64, 1, 28, 28])
# Y 353:	torch.Size([64])
# X 354:	torch.Size([64, 1, 28, 28])
# Y 354:	torch.Size([64])
# X 355:	torch.Size([64, 1, 28, 28])
# Y 355:	torch.Size([64])
# X 356:	torch.Size([64, 1, 28, 28])
# Y 356:	torch.Size([64])
# X 357:	torch.Size([64, 1, 28, 28])
# Y 357:	torch.Size([64])
# X 358:	torch.Size([64, 1, 28, 28])
# Y 358:	torch.Size([64])
# X 359:	torch.Size([64, 1, 28, 28])
# Y 359:	torch.Size([64])
# X 360:	torch.Size([64, 1, 28, 28])
# Y 360:	torch.Size([64])
# X 361:	torch.Size([64, 1, 28, 28])
# Y 361:	torch.Size([64])
# X 362:	torch.Size([64, 1, 28, 28])
# Y 362:	torch.Size([64])
# X 363:	torch.Size([64, 1, 28, 28])
# Y 363:	torch.Size([64])
# X 364:	torch.Size([64, 1, 28, 28])
# Y 364:	torch.Size([64])
# X 365:	torch.Size([64, 1, 28, 28])
# Y 365:	torch.Size([64])
# X 366:	torch.Size([64, 1, 28, 28])
# Y 366:	torch.Size([64])
# X 367:	torch.Size([64, 1, 28, 28])
# Y 367:	torch.Size([64])
# X 368:	torch.Size([64, 1, 28, 28])
# Y 368:	torch.Size([64])
# X 369:	torch.Size([64, 1, 28, 28])
# Y 369:	torch.Size([64])
# X 370:	torch.Size([64, 1, 28, 28])
# Y 370:	torch.Size([64])
# X 371:	torch.Size([64, 1, 28, 28])
# Y 371:	torch.Size([64])
# X 372:	torch.Size([64, 1, 28, 28])
# Y 372:	torch.Size([64])
# X 373:	torch.Size([64, 1, 28, 28])
# Y 373:	torch.Size([64])
# X 374:	torch.Size([64, 1, 28, 28])
# Y 374:	torch.Size([64])
# X 375:	torch.Size([64, 1, 28, 28])
# Y 375:	torch.Size([64])
# X 376:	torch.Size([64, 1, 28, 28])
# Y 376:	torch.Size([64])
# X 377:	torch.Size([64, 1, 28, 28])
# Y 377:	torch.Size([64])
# X 378:	torch.Size([64, 1, 28, 28])
# Y 378:	torch.Size([64])
# X 379:	torch.Size([64, 1, 28, 28])
# Y 379:	torch.Size([64])
# X 380:	torch.Size([64, 1, 28, 28])
# Y 380:	torch.Size([64])
# X 381:	torch.Size([64, 1, 28, 28])
# Y 381:	torch.Size([64])
# X 382:	torch.Size([64, 1, 28, 28])
# Y 382:	torch.Size([64])
# X 383:	torch.Size([64, 1, 28, 28])
# Y 383:	torch.Size([64])
# X 384:	torch.Size([64, 1, 28, 28])
# Y 384:	torch.Size([64])
# X 385:	torch.Size([64, 1, 28, 28])
# Y 385:	torch.Size([64])
# X 386:	torch.Size([64, 1, 28, 28])
# Y 386:	torch.Size([64])
# X 387:	torch.Size([64, 1, 28, 28])
# Y 387:	torch.Size([64])
# X 388:	torch.Size([64, 1, 28, 28])
# Y 388:	torch.Size([64])
# X 389:	torch.Size([64, 1, 28, 28])
# Y 389:	torch.Size([64])
# X 390:	torch.Size([64, 1, 28, 28])
# Y 390:	torch.Size([64])
# X 391:	torch.Size([64, 1, 28, 28])
# Y 391:	torch.Size([64])
# X 392:	torch.Size([64, 1, 28, 28])
# Y 392:	torch.Size([64])
# X 393:	torch.Size([64, 1, 28, 28])
# Y 393:	torch.Size([64])
# X 394:	torch.Size([64, 1, 28, 28])
# Y 394:	torch.Size([64])
# X 395:	torch.Size([64, 1, 28, 28])
# Y 395:	torch.Size([64])
# X 396:	torch.Size([64, 1, 28, 28])
# Y 396:	torch.Size([64])
# X 397:	torch.Size([64, 1, 28, 28])
# Y 397:	torch.Size([64])
# X 398:	torch.Size([64, 1, 28, 28])
# Y 398:	torch.Size([64])
# X 399:	torch.Size([64, 1, 28, 28])
# Y 399:	torch.Size([64])
# X 400:	torch.Size([64, 1, 28, 28])
# Y 400:	torch.Size([64])
# X 401:	torch.Size([64, 1, 28, 28])
# Y 401:	torch.Size([64])
# X 402:	torch.Size([64, 1, 28, 28])
# Y 402:	torch.Size([64])
# X 403:	torch.Size([64, 1, 28, 28])
# Y 403:	torch.Size([64])
# X 404:	torch.Size([64, 1, 28, 28])
# Y 404:	torch.Size([64])
# X 405:	torch.Size([64, 1, 28, 28])
# Y 405:	torch.Size([64])
# X 406:	torch.Size([64, 1, 28, 28])
# Y 406:	torch.Size([64])
# X 407:	torch.Size([64, 1, 28, 28])
# Y 407:	torch.Size([64])
# X 408:	torch.Size([64, 1, 28, 28])
# Y 408:	torch.Size([64])
# X 409:	torch.Size([64, 1, 28, 28])
# Y 409:	torch.Size([64])
# X 410:	torch.Size([64, 1, 28, 28])
# Y 410:	torch.Size([64])
# X 411:	torch.Size([64, 1, 28, 28])
# Y 411:	torch.Size([64])
# X 412:	torch.Size([64, 1, 28, 28])
# Y 412:	torch.Size([64])
# X 413:	torch.Size([64, 1, 28, 28])
# Y 413:	torch.Size([64])
# X 414:	torch.Size([64, 1, 28, 28])
# Y 414:	torch.Size([64])
# X 415:	torch.Size([64, 1, 28, 28])
# Y 415:	torch.Size([64])
# X 416:	torch.Size([64, 1, 28, 28])
# Y 416:	torch.Size([64])
# X 417:	torch.Size([64, 1, 28, 28])
# Y 417:	torch.Size([64])
# X 418:	torch.Size([64, 1, 28, 28])
# Y 418:	torch.Size([64])
# X 419:	torch.Size([64, 1, 28, 28])
# Y 419:	torch.Size([64])
# X 420:	torch.Size([64, 1, 28, 28])
# Y 420:	torch.Size([64])
# X 421:	torch.Size([64, 1, 28, 28])
# Y 421:	torch.Size([64])
# X 422:	torch.Size([64, 1, 28, 28])
# Y 422:	torch.Size([64])
# X 423:	torch.Size([64, 1, 28, 28])
# Y 423:	torch.Size([64])
# X 424:	torch.Size([64, 1, 28, 28])
# Y 424:	torch.Size([64])
# X 425:	torch.Size([64, 1, 28, 28])
# Y 425:	torch.Size([64])
# X 426:	torch.Size([64, 1, 28, 28])
# Y 426:	torch.Size([64])
# X 427:	torch.Size([64, 1, 28, 28])
# Y 427:	torch.Size([64])
# X 428:	torch.Size([64, 1, 28, 28])
# Y 428:	torch.Size([64])
# X 429:	torch.Size([64, 1, 28, 28])
# Y 429:	torch.Size([64])
# X 430:	torch.Size([64, 1, 28, 28])
# Y 430:	torch.Size([64])
# X 431:	torch.Size([64, 1, 28, 28])
# Y 431:	torch.Size([64])
# X 432:	torch.Size([64, 1, 28, 28])
# Y 432:	torch.Size([64])
# X 433:	torch.Size([64, 1, 28, 28])
# Y 433:	torch.Size([64])
# X 434:	torch.Size([64, 1, 28, 28])
# Y 434:	torch.Size([64])
# X 435:	torch.Size([64, 1, 28, 28])
# Y 435:	torch.Size([64])
# X 436:	torch.Size([64, 1, 28, 28])
# Y 436:	torch.Size([64])
# X 437:	torch.Size([64, 1, 28, 28])
# Y 437:	torch.Size([64])
# X 438:	torch.Size([64, 1, 28, 28])
# Y 438:	torch.Size([64])
# X 439:	torch.Size([64, 1, 28, 28])
# Y 439:	torch.Size([64])
# X 440:	torch.Size([64, 1, 28, 28])
# Y 440:	torch.Size([64])
# X 441:	torch.Size([64, 1, 28, 28])
# Y 441:	torch.Size([64])
# X 442:	torch.Size([64, 1, 28, 28])
# Y 442:	torch.Size([64])
# X 443:	torch.Size([64, 1, 28, 28])
# Y 443:	torch.Size([64])
# X 444:	torch.Size([64, 1, 28, 28])
# Y 444:	torch.Size([64])
# X 445:	torch.Size([64, 1, 28, 28])
# Y 445:	torch.Size([64])
# X 446:	torch.Size([64, 1, 28, 28])
# Y 446:	torch.Size([64])
# X 447:	torch.Size([64, 1, 28, 28])
# Y 447:	torch.Size([64])
# X 448:	torch.Size([64, 1, 28, 28])
# Y 448:	torch.Size([64])
# X 449:	torch.Size([64, 1, 28, 28])
# Y 449:	torch.Size([64])
# X 450:	torch.Size([64, 1, 28, 28])
# Y 450:	torch.Size([64])
# X 451:	torch.Size([64, 1, 28, 28])
# Y 451:	torch.Size([64])
# X 452:	torch.Size([64, 1, 28, 28])
# Y 452:	torch.Size([64])
# X 453:	torch.Size([64, 1, 28, 28])
# Y 453:	torch.Size([64])
# X 454:	torch.Size([64, 1, 28, 28])
# Y 454:	torch.Size([64])
# X 455:	torch.Size([64, 1, 28, 28])
# Y 455:	torch.Size([64])
# X 456:	torch.Size([64, 1, 28, 28])
# Y 456:	torch.Size([64])
# X 457:	torch.Size([64, 1, 28, 28])
# Y 457:	torch.Size([64])
# X 458:	torch.Size([64, 1, 28, 28])
# Y 458:	torch.Size([64])
# X 459:	torch.Size([64, 1, 28, 28])
# Y 459:	torch.Size([64])
# X 460:	torch.Size([64, 1, 28, 28])
# Y 460:	torch.Size([64])
# X 461:	torch.Size([64, 1, 28, 28])
# Y 461:	torch.Size([64])
# X 462:	torch.Size([64, 1, 28, 28])
# Y 462:	torch.Size([64])
# X 463:	torch.Size([64, 1, 28, 28])
# Y 463:	torch.Size([64])
# X 464:	torch.Size([64, 1, 28, 28])
# Y 464:	torch.Size([64])
# X 465:	torch.Size([64, 1, 28, 28])
# Y 465:	torch.Size([64])
# X 466:	torch.Size([64, 1, 28, 28])
# Y 466:	torch.Size([64])
# X 467:	torch.Size([64, 1, 28, 28])
# Y 467:	torch.Size([64])
# X 468:	torch.Size([64, 1, 28, 28])
# Y 468:	torch.Size([64])
# X 469:	torch.Size([64, 1, 28, 28])
# Y 469:	torch.Size([64])
# X 470:	torch.Size([64, 1, 28, 28])
# Y 470:	torch.Size([64])
# X 471:	torch.Size([64, 1, 28, 28])
# Y 471:	torch.Size([64])
# X 472:	torch.Size([64, 1, 28, 28])
# Y 472:	torch.Size([64])
# X 473:	torch.Size([64, 1, 28, 28])
# Y 473:	torch.Size([64])
# X 474:	torch.Size([64, 1, 28, 28])
# Y 474:	torch.Size([64])
# X 475:	torch.Size([64, 1, 28, 28])
# Y 475:	torch.Size([64])
# X 476:	torch.Size([64, 1, 28, 28])
# Y 476:	torch.Size([64])
# X 477:	torch.Size([64, 1, 28, 28])
# Y 477:	torch.Size([64])
# X 478:	torch.Size([64, 1, 28, 28])
# Y 478:	torch.Size([64])
# X 479:	torch.Size([64, 1, 28, 28])
# Y 479:	torch.Size([64])
# X 480:	torch.Size([64, 1, 28, 28])
# Y 480:	torch.Size([64])
# X 481:	torch.Size([64, 1, 28, 28])
# Y 481:	torch.Size([64])
# X 482:	torch.Size([64, 1, 28, 28])
# Y 482:	torch.Size([64])
# X 483:	torch.Size([64, 1, 28, 28])
# Y 483:	torch.Size([64])
# X 484:	torch.Size([64, 1, 28, 28])
# Y 484:	torch.Size([64])
# X 485:	torch.Size([64, 1, 28, 28])
# Y 485:	torch.Size([64])
# X 486:	torch.Size([64, 1, 28, 28])
# Y 486:	torch.Size([64])
# X 487:	torch.Size([64, 1, 28, 28])
# Y 487:	torch.Size([64])
# X 488:	torch.Size([64, 1, 28, 28])
# Y 488:	torch.Size([64])
# X 489:	torch.Size([64, 1, 28, 28])
# Y 489:	torch.Size([64])
# X 490:	torch.Size([64, 1, 28, 28])
# Y 490:	torch.Size([64])
# X 491:	torch.Size([64, 1, 28, 28])
# Y 491:	torch.Size([64])
# X 492:	torch.Size([64, 1, 28, 28])
# Y 492:	torch.Size([64])
# X 493:	torch.Size([64, 1, 28, 28])
# Y 493:	torch.Size([64])
# X 494:	torch.Size([64, 1, 28, 28])
# Y 494:	torch.Size([64])
# X 495:	torch.Size([64, 1, 28, 28])
# Y 495:	torch.Size([64])
# X 496:	torch.Size([64, 1, 28, 28])
# Y 496:	torch.Size([64])
# X 497:	torch.Size([64, 1, 28, 28])
# Y 497:	torch.Size([64])
# X 498:	torch.Size([64, 1, 28, 28])
# Y 498:	torch.Size([64])
# X 499:	torch.Size([64, 1, 28, 28])
# Y 499:	torch.Size([64])
# X 500:	torch.Size([64, 1, 28, 28])
# Y 500:	torch.Size([64])
# X 501:	torch.Size([64, 1, 28, 28])
# Y 501:	torch.Size([64])
# X 502:	torch.Size([64, 1, 28, 28])
# Y 502:	torch.Size([64])
# X 503:	torch.Size([64, 1, 28, 28])
# Y 503:	torch.Size([64])
# X 504:	torch.Size([64, 1, 28, 28])
# Y 504:	torch.Size([64])
# X 505:	torch.Size([64, 1, 28, 28])
# Y 505:	torch.Size([64])
# X 506:	torch.Size([64, 1, 28, 28])
# Y 506:	torch.Size([64])
# X 507:	torch.Size([64, 1, 28, 28])
# Y 507:	torch.Size([64])
# X 508:	torch.Size([64, 1, 28, 28])
# Y 508:	torch.Size([64])
# X 509:	torch.Size([64, 1, 28, 28])
# Y 509:	torch.Size([64])
# X 510:	torch.Size([64, 1, 28, 28])
# Y 510:	torch.Size([64])
# X 511:	torch.Size([64, 1, 28, 28])
# Y 511:	torch.Size([64])
# X 512:	torch.Size([64, 1, 28, 28])
# Y 512:	torch.Size([64])
# X 513:	torch.Size([64, 1, 28, 28])
# Y 513:	torch.Size([64])
# X 514:	torch.Size([64, 1, 28, 28])
# Y 514:	torch.Size([64])
# X 515:	torch.Size([64, 1, 28, 28])
# Y 515:	torch.Size([64])
# X 516:	torch.Size([64, 1, 28, 28])
# Y 516:	torch.Size([64])
# X 517:	torch.Size([64, 1, 28, 28])
# Y 517:	torch.Size([64])
# X 518:	torch.Size([64, 1, 28, 28])
# Y 518:	torch.Size([64])
# X 519:	torch.Size([64, 1, 28, 28])
# Y 519:	torch.Size([64])
# X 520:	torch.Size([64, 1, 28, 28])
# Y 520:	torch.Size([64])
# X 521:	torch.Size([64, 1, 28, 28])
# Y 521:	torch.Size([64])
# X 522:	torch.Size([64, 1, 28, 28])
# Y 522:	torch.Size([64])
# X 523:	torch.Size([64, 1, 28, 28])
# Y 523:	torch.Size([64])
# X 524:	torch.Size([64, 1, 28, 28])
# Y 524:	torch.Size([64])
# X 525:	torch.Size([64, 1, 28, 28])
# Y 525:	torch.Size([64])
# X 526:	torch.Size([64, 1, 28, 28])
# Y 526:	torch.Size([64])
# X 527:	torch.Size([64, 1, 28, 28])
# Y 527:	torch.Size([64])
# X 528:	torch.Size([64, 1, 28, 28])
# Y 528:	torch.Size([64])
# X 529:	torch.Size([64, 1, 28, 28])
# Y 529:	torch.Size([64])
# X 530:	torch.Size([64, 1, 28, 28])
# Y 530:	torch.Size([64])
# X 531:	torch.Size([64, 1, 28, 28])
# Y 531:	torch.Size([64])
# X 532:	torch.Size([64, 1, 28, 28])
# Y 532:	torch.Size([64])
# X 533:	torch.Size([64, 1, 28, 28])
# Y 533:	torch.Size([64])
# X 534:	torch.Size([64, 1, 28, 28])
# Y 534:	torch.Size([64])
# X 535:	torch.Size([64, 1, 28, 28])
# Y 535:	torch.Size([64])
# X 536:	torch.Size([64, 1, 28, 28])
# Y 536:	torch.Size([64])
# X 537:	torch.Size([64, 1, 28, 28])
# Y 537:	torch.Size([64])
# X 538:	torch.Size([64, 1, 28, 28])
# Y 538:	torch.Size([64])
# X 539:	torch.Size([64, 1, 28, 28])
# Y 539:	torch.Size([64])
# X 540:	torch.Size([64, 1, 28, 28])
# Y 540:	torch.Size([64])
# X 541:	torch.Size([64, 1, 28, 28])
# Y 541:	torch.Size([64])
# X 542:	torch.Size([64, 1, 28, 28])
# Y 542:	torch.Size([64])
# X 543:	torch.Size([64, 1, 28, 28])
# Y 543:	torch.Size([64])
# X 544:	torch.Size([64, 1, 28, 28])
# Y 544:	torch.Size([64])
# X 545:	torch.Size([64, 1, 28, 28])
# Y 545:	torch.Size([64])
# X 546:	torch.Size([64, 1, 28, 28])
# Y 546:	torch.Size([64])
# X 547:	torch.Size([64, 1, 28, 28])
# Y 547:	torch.Size([64])
# X 548:	torch.Size([64, 1, 28, 28])
# Y 548:	torch.Size([64])
# X 549:	torch.Size([64, 1, 28, 28])
# Y 549:	torch.Size([64])
# X 550:	torch.Size([64, 1, 28, 28])
# Y 550:	torch.Size([64])
# X 551:	torch.Size([64, 1, 28, 28])
# Y 551:	torch.Size([64])
# X 552:	torch.Size([64, 1, 28, 28])
# Y 552:	torch.Size([64])
# X 553:	torch.Size([64, 1, 28, 28])
# Y 553:	torch.Size([64])
# X 554:	torch.Size([64, 1, 28, 28])
# Y 554:	torch.Size([64])
# X 555:	torch.Size([64, 1, 28, 28])
# Y 555:	torch.Size([64])
# X 556:	torch.Size([64, 1, 28, 28])
# Y 556:	torch.Size([64])
# X 557:	torch.Size([64, 1, 28, 28])
# Y 557:	torch.Size([64])
# X 558:	torch.Size([64, 1, 28, 28])
# Y 558:	torch.Size([64])
# X 559:	torch.Size([64, 1, 28, 28])
# Y 559:	torch.Size([64])
# X 560:	torch.Size([64, 1, 28, 28])
# Y 560:	torch.Size([64])
# X 561:	torch.Size([64, 1, 28, 28])
# Y 561:	torch.Size([64])
# X 562:	torch.Size([64, 1, 28, 28])
# Y 562:	torch.Size([64])
# X 563:	torch.Size([64, 1, 28, 28])
# Y 563:	torch.Size([64])
# X 564:	torch.Size([64, 1, 28, 28])
# Y 564:	torch.Size([64])
# X 565:	torch.Size([64, 1, 28, 28])
# Y 565:	torch.Size([64])
# X 566:	torch.Size([64, 1, 28, 28])
# Y 566:	torch.Size([64])
# X 567:	torch.Size([64, 1, 28, 28])
# Y 567:	torch.Size([64])
# X 568:	torch.Size([64, 1, 28, 28])
# Y 568:	torch.Size([64])
# X 569:	torch.Size([64, 1, 28, 28])
# Y 569:	torch.Size([64])
# X 570:	torch.Size([64, 1, 28, 28])
# Y 570:	torch.Size([64])
# X 571:	torch.Size([64, 1, 28, 28])
# Y 571:	torch.Size([64])
# X 572:	torch.Size([64, 1, 28, 28])
# Y 572:	torch.Size([64])
# X 573:	torch.Size([64, 1, 28, 28])
# Y 573:	torch.Size([64])
# X 574:	torch.Size([64, 1, 28, 28])
# Y 574:	torch.Size([64])
# X 575:	torch.Size([64, 1, 28, 28])
# Y 575:	torch.Size([64])
# X 576:	torch.Size([64, 1, 28, 28])
# Y 576:	torch.Size([64])
# X 577:	torch.Size([64, 1, 28, 28])
# Y 577:	torch.Size([64])
# X 578:	torch.Size([64, 1, 28, 28])
# Y 578:	torch.Size([64])
# X 579:	torch.Size([64, 1, 28, 28])
# Y 579:	torch.Size([64])
# X 580:	torch.Size([64, 1, 28, 28])
# Y 580:	torch.Size([64])
# X 581:	torch.Size([64, 1, 28, 28])
# Y 581:	torch.Size([64])
# X 582:	torch.Size([64, 1, 28, 28])
# Y 582:	torch.Size([64])
# X 583:	torch.Size([64, 1, 28, 28])
# Y 583:	torch.Size([64])
# X 584:	torch.Size([64, 1, 28, 28])
# Y 584:	torch.Size([64])
# X 585:	torch.Size([64, 1, 28, 28])
# Y 585:	torch.Size([64])
# X 586:	torch.Size([64, 1, 28, 28])
# Y 586:	torch.Size([64])
# X 587:	torch.Size([64, 1, 28, 28])
# Y 587:	torch.Size([64])
# X 588:	torch.Size([64, 1, 28, 28])
# Y 588:	torch.Size([64])
# X 589:	torch.Size([64, 1, 28, 28])
# Y 589:	torch.Size([64])
# X 590:	torch.Size([64, 1, 28, 28])
# Y 590:	torch.Size([64])
# X 591:	torch.Size([64, 1, 28, 28])
# Y 591:	torch.Size([64])
# X 592:	torch.Size([64, 1, 28, 28])
# Y 592:	torch.Size([64])
# X 593:	torch.Size([64, 1, 28, 28])
# Y 593:	torch.Size([64])
# X 594:	torch.Size([64, 1, 28, 28])
# Y 594:	torch.Size([64])
# X 595:	torch.Size([64, 1, 28, 28])
# Y 595:	torch.Size([64])
# X 596:	torch.Size([64, 1, 28, 28])
# Y 596:	torch.Size([64])
# X 597:	torch.Size([64, 1, 28, 28])
# Y 597:	torch.Size([64])
# X 598:	torch.Size([64, 1, 28, 28])
# Y 598:	torch.Size([64])
# X 599:	torch.Size([64, 1, 28, 28])
# Y 599:	torch.Size([64])
# X 600:	torch.Size([64, 1, 28, 28])
# Y 600:	torch.Size([64])
# X 601:	torch.Size([64, 1, 28, 28])
# Y 601:	torch.Size([64])
# X 602:	torch.Size([64, 1, 28, 28])
# Y 602:	torch.Size([64])
# X 603:	torch.Size([64, 1, 28, 28])
# Y 603:	torch.Size([64])
# X 604:	torch.Size([64, 1, 28, 28])
# Y 604:	torch.Size([64])
# X 605:	torch.Size([64, 1, 28, 28])
# Y 605:	torch.Size([64])
# X 606:	torch.Size([64, 1, 28, 28])
# Y 606:	torch.Size([64])
# X 607:	torch.Size([64, 1, 28, 28])
# Y 607:	torch.Size([64])
# X 608:	torch.Size([64, 1, 28, 28])
# Y 608:	torch.Size([64])
# X 609:	torch.Size([64, 1, 28, 28])
# Y 609:	torch.Size([64])
# X 610:	torch.Size([64, 1, 28, 28])
# Y 610:	torch.Size([64])
# X 611:	torch.Size([64, 1, 28, 28])
# Y 611:	torch.Size([64])
# X 612:	torch.Size([64, 1, 28, 28])
# Y 612:	torch.Size([64])
# X 613:	torch.Size([64, 1, 28, 28])
# Y 613:	torch.Size([64])
# X 614:	torch.Size([64, 1, 28, 28])
# Y 614:	torch.Size([64])
# X 615:	torch.Size([64, 1, 28, 28])
# Y 615:	torch.Size([64])
# X 616:	torch.Size([64, 1, 28, 28])
# Y 616:	torch.Size([64])
# X 617:	torch.Size([64, 1, 28, 28])
# Y 617:	torch.Size([64])
# X 618:	torch.Size([64, 1, 28, 28])
# Y 618:	torch.Size([64])
# X 619:	torch.Size([64, 1, 28, 28])
# Y 619:	torch.Size([64])
# X 620:	torch.Size([64, 1, 28, 28])
# Y 620:	torch.Size([64])
# X 621:	torch.Size([64, 1, 28, 28])
# Y 621:	torch.Size([64])
# X 622:	torch.Size([64, 1, 28, 28])
# Y 622:	torch.Size([64])
# X 623:	torch.Size([64, 1, 28, 28])
# Y 623:	torch.Size([64])
# X 624:	torch.Size([64, 1, 28, 28])
# Y 624:	torch.Size([64])
# X 625:	torch.Size([64, 1, 28, 28])
# Y 625:	torch.Size([64])
# X 626:	torch.Size([64, 1, 28, 28])
# Y 626:	torch.Size([64])
# X 627:	torch.Size([64, 1, 28, 28])
# Y 627:	torch.Size([64])
# X 628:	torch.Size([64, 1, 28, 28])
# Y 628:	torch.Size([64])
# X 629:	torch.Size([64, 1, 28, 28])
# Y 629:	torch.Size([64])
# X 630:	torch.Size([64, 1, 28, 28])
# Y 630:	torch.Size([64])
# X 631:	torch.Size([64, 1, 28, 28])
# Y 631:	torch.Size([64])
# X 632:	torch.Size([64, 1, 28, 28])
# Y 632:	torch.Size([64])
# X 633:	torch.Size([64, 1, 28, 28])
# Y 633:	torch.Size([64])
# X 634:	torch.Size([64, 1, 28, 28])
# Y 634:	torch.Size([64])
# X 635:	torch.Size([64, 1, 28, 28])
# Y 635:	torch.Size([64])
# X 636:	torch.Size([64, 1, 28, 28])
# Y 636:	torch.Size([64])
# X 637:	torch.Size([64, 1, 28, 28])
# Y 637:	torch.Size([64])
# X 638:	torch.Size([64, 1, 28, 28])
# Y 638:	torch.Size([64])
# X 639:	torch.Size([64, 1, 28, 28])
# Y 639:	torch.Size([64])
# X 640:	torch.Size([64, 1, 28, 28])
# Y 640:	torch.Size([64])
# X 641:	torch.Size([64, 1, 28, 28])
# Y 641:	torch.Size([64])
# X 642:	torch.Size([64, 1, 28, 28])
# Y 642:	torch.Size([64])
# X 643:	torch.Size([64, 1, 28, 28])
# Y 643:	torch.Size([64])
# X 644:	torch.Size([64, 1, 28, 28])
# Y 644:	torch.Size([64])
# X 645:	torch.Size([64, 1, 28, 28])
# Y 645:	torch.Size([64])
# X 646:	torch.Size([64, 1, 28, 28])
# Y 646:	torch.Size([64])
# X 647:	torch.Size([64, 1, 28, 28])
# Y 647:	torch.Size([64])
# X 648:	torch.Size([64, 1, 28, 28])
# Y 648:	torch.Size([64])
# X 649:	torch.Size([64, 1, 28, 28])
# Y 649:	torch.Size([64])
# X 650:	torch.Size([64, 1, 28, 28])
# Y 650:	torch.Size([64])
# X 651:	torch.Size([64, 1, 28, 28])
# Y 651:	torch.Size([64])
# X 652:	torch.Size([64, 1, 28, 28])
# Y 652:	torch.Size([64])
# X 653:	torch.Size([64, 1, 28, 28])
# Y 653:	torch.Size([64])
# X 654:	torch.Size([64, 1, 28, 28])
# Y 654:	torch.Size([64])
# X 655:	torch.Size([64, 1, 28, 28])
# Y 655:	torch.Size([64])
# X 656:	torch.Size([64, 1, 28, 28])
# Y 656:	torch.Size([64])
# X 657:	torch.Size([64, 1, 28, 28])
# Y 657:	torch.Size([64])
# X 658:	torch.Size([64, 1, 28, 28])
# Y 658:	torch.Size([64])
# X 659:	torch.Size([64, 1, 28, 28])
# Y 659:	torch.Size([64])
# X 660:	torch.Size([64, 1, 28, 28])
# Y 660:	torch.Size([64])
# X 661:	torch.Size([64, 1, 28, 28])
# Y 661:	torch.Size([64])
# X 662:	torch.Size([64, 1, 28, 28])
# Y 662:	torch.Size([64])
# X 663:	torch.Size([64, 1, 28, 28])
# Y 663:	torch.Size([64])
# X 664:	torch.Size([64, 1, 28, 28])
# Y 664:	torch.Size([64])
# X 665:	torch.Size([64, 1, 28, 28])
# Y 665:	torch.Size([64])
# X 666:	torch.Size([64, 1, 28, 28])
# Y 666:	torch.Size([64])
# X 667:	torch.Size([64, 1, 28, 28])
# Y 667:	torch.Size([64])
# X 668:	torch.Size([64, 1, 28, 28])
# Y 668:	torch.Size([64])
# X 669:	torch.Size([64, 1, 28, 28])
# Y 669:	torch.Size([64])
# X 670:	torch.Size([64, 1, 28, 28])
# Y 670:	torch.Size([64])
# X 671:	torch.Size([64, 1, 28, 28])
# Y 671:	torch.Size([64])
# X 672:	torch.Size([64, 1, 28, 28])
# Y 672:	torch.Size([64])
# X 673:	torch.Size([64, 1, 28, 28])
# Y 673:	torch.Size([64])
# X 674:	torch.Size([64, 1, 28, 28])
# Y 674:	torch.Size([64])
# X 675:	torch.Size([64, 1, 28, 28])
# Y 675:	torch.Size([64])
# X 676:	torch.Size([64, 1, 28, 28])
# Y 676:	torch.Size([64])
# X 677:	torch.Size([64, 1, 28, 28])
# Y 677:	torch.Size([64])
# X 678:	torch.Size([64, 1, 28, 28])
# Y 678:	torch.Size([64])
# X 679:	torch.Size([64, 1, 28, 28])
# Y 679:	torch.Size([64])
# X 680:	torch.Size([64, 1, 28, 28])
# Y 680:	torch.Size([64])
# X 681:	torch.Size([64, 1, 28, 28])
# Y 681:	torch.Size([64])
# X 682:	torch.Size([64, 1, 28, 28])
# Y 682:	torch.Size([64])
# X 683:	torch.Size([64, 1, 28, 28])
# Y 683:	torch.Size([64])
# X 684:	torch.Size([64, 1, 28, 28])
# Y 684:	torch.Size([64])
# X 685:	torch.Size([64, 1, 28, 28])
# Y 685:	torch.Size([64])
# X 686:	torch.Size([64, 1, 28, 28])
# Y 686:	torch.Size([64])
# X 687:	torch.Size([64, 1, 28, 28])
# Y 687:	torch.Size([64])
# X 688:	torch.Size([64, 1, 28, 28])
# Y 688:	torch.Size([64])
# X 689:	torch.Size([64, 1, 28, 28])
# Y 689:	torch.Size([64])
# X 690:	torch.Size([64, 1, 28, 28])
# Y 690:	torch.Size([64])
# X 691:	torch.Size([64, 1, 28, 28])
# Y 691:	torch.Size([64])
# X 692:	torch.Size([64, 1, 28, 28])
# Y 692:	torch.Size([64])
# X 693:	torch.Size([64, 1, 28, 28])
# Y 693:	torch.Size([64])
# X 694:	torch.Size([64, 1, 28, 28])
# Y 694:	torch.Size([64])
# X 695:	torch.Size([64, 1, 28, 28])
# Y 695:	torch.Size([64])
# X 696:	torch.Size([64, 1, 28, 28])
# Y 696:	torch.Size([64])
# X 697:	torch.Size([64, 1, 28, 28])
# Y 697:	torch.Size([64])
# X 698:	torch.Size([64, 1, 28, 28])
# Y 698:	torch.Size([64])
# X 699:	torch.Size([64, 1, 28, 28])
# Y 699:	torch.Size([64])
# X 700:	torch.Size([64, 1, 28, 28])
# Y 700:	torch.Size([64])
# X 701:	torch.Size([64, 1, 28, 28])
# Y 701:	torch.Size([64])
# X 702:	torch.Size([64, 1, 28, 28])
# Y 702:	torch.Size([64])
# X 703:	torch.Size([64, 1, 28, 28])
# Y 703:	torch.Size([64])
# X 704:	torch.Size([64, 1, 28, 28])
# Y 704:	torch.Size([64])
# X 705:	torch.Size([64, 1, 28, 28])
# Y 705:	torch.Size([64])
# X 706:	torch.Size([64, 1, 28, 28])
# Y 706:	torch.Size([64])
# X 707:	torch.Size([64, 1, 28, 28])
# Y 707:	torch.Size([64])
# X 708:	torch.Size([64, 1, 28, 28])
# Y 708:	torch.Size([64])
# X 709:	torch.Size([64, 1, 28, 28])
# Y 709:	torch.Size([64])
# X 710:	torch.Size([64, 1, 28, 28])
# Y 710:	torch.Size([64])
# X 711:	torch.Size([64, 1, 28, 28])
# Y 711:	torch.Size([64])
# X 712:	torch.Size([64, 1, 28, 28])
# Y 712:	torch.Size([64])
# X 713:	torch.Size([64, 1, 28, 28])
# Y 713:	torch.Size([64])
# X 714:	torch.Size([64, 1, 28, 28])
# Y 714:	torch.Size([64])
# X 715:	torch.Size([64, 1, 28, 28])
# Y 715:	torch.Size([64])
# X 716:	torch.Size([64, 1, 28, 28])
# Y 716:	torch.Size([64])
# X 717:	torch.Size([64, 1, 28, 28])
# Y 717:	torch.Size([64])
# X 718:	torch.Size([64, 1, 28, 28])
# Y 718:	torch.Size([64])
# X 719:	torch.Size([64, 1, 28, 28])
# Y 719:	torch.Size([64])
# X 720:	torch.Size([64, 1, 28, 28])
# Y 720:	torch.Size([64])
# X 721:	torch.Size([64, 1, 28, 28])
# Y 721:	torch.Size([64])
# X 722:	torch.Size([64, 1, 28, 28])
# Y 722:	torch.Size([64])
# X 723:	torch.Size([64, 1, 28, 28])
# Y 723:	torch.Size([64])
# X 724:	torch.Size([64, 1, 28, 28])
# Y 724:	torch.Size([64])
# X 725:	torch.Size([64, 1, 28, 28])
# Y 725:	torch.Size([64])
# X 726:	torch.Size([64, 1, 28, 28])
# Y 726:	torch.Size([64])
# X 727:	torch.Size([64, 1, 28, 28])
# Y 727:	torch.Size([64])
# X 728:	torch.Size([64, 1, 28, 28])
# Y 728:	torch.Size([64])
# X 729:	torch.Size([64, 1, 28, 28])
# Y 729:	torch.Size([64])
# X 730:	torch.Size([64, 1, 28, 28])
# Y 730:	torch.Size([64])
# X 731:	torch.Size([64, 1, 28, 28])
# Y 731:	torch.Size([64])
# X 732:	torch.Size([64, 1, 28, 28])
# Y 732:	torch.Size([64])
# X 733:	torch.Size([64, 1, 28, 28])
# Y 733:	torch.Size([64])
# X 734:	torch.Size([64, 1, 28, 28])
# Y 734:	torch.Size([64])
# X 735:	torch.Size([64, 1, 28, 28])
# Y 735:	torch.Size([64])
# X 736:	torch.Size([64, 1, 28, 28])
# Y 736:	torch.Size([64])
# X 737:	torch.Size([64, 1, 28, 28])
# Y 737:	torch.Size([64])
# X 738:	torch.Size([64, 1, 28, 28])
# Y 738:	torch.Size([64])
# X 739:	torch.Size([64, 1, 28, 28])
# Y 739:	torch.Size([64])
# X 740:	torch.Size([64, 1, 28, 28])
# Y 740:	torch.Size([64])
# X 741:	torch.Size([64, 1, 28, 28])
# Y 741:	torch.Size([64])
# X 742:	torch.Size([64, 1, 28, 28])
# Y 742:	torch.Size([64])
# X 743:	torch.Size([64, 1, 28, 28])
# Y 743:	torch.Size([64])
# X 744:	torch.Size([64, 1, 28, 28])
# Y 744:	torch.Size([64])
# X 745:	torch.Size([64, 1, 28, 28])
# Y 745:	torch.Size([64])
# X 746:	torch.Size([64, 1, 28, 28])
# Y 746:	torch.Size([64])
# X 747:	torch.Size([64, 1, 28, 28])
# Y 747:	torch.Size([64])
# X 748:	torch.Size([64, 1, 28, 28])
# Y 748:	torch.Size([64])
# X 749:	torch.Size([64, 1, 28, 28])
# Y 749:	torch.Size([64])
# X 750:	torch.Size([64, 1, 28, 28])
# Y 750:	torch.Size([64])
# X 751:	torch.Size([64, 1, 28, 28])
# Y 751:	torch.Size([64])
# X 752:	torch.Size([64, 1, 28, 28])
# Y 752:	torch.Size([64])
# X 753:	torch.Size([64, 1, 28, 28])
# Y 753:	torch.Size([64])
# X 754:	torch.Size([64, 1, 28, 28])
# Y 754:	torch.Size([64])
# X 755:	torch.Size([64, 1, 28, 28])
# Y 755:	torch.Size([64])
# X 756:	torch.Size([64, 1, 28, 28])
# Y 756:	torch.Size([64])
# X 757:	torch.Size([64, 1, 28, 28])
# Y 757:	torch.Size([64])
# X 758:	torch.Size([64, 1, 28, 28])
# Y 758:	torch.Size([64])
# X 759:	torch.Size([64, 1, 28, 28])
# Y 759:	torch.Size([64])
# X 760:	torch.Size([64, 1, 28, 28])
# Y 760:	torch.Size([64])
# X 761:	torch.Size([64, 1, 28, 28])
# Y 761:	torch.Size([64])
# X 762:	torch.Size([64, 1, 28, 28])
# Y 762:	torch.Size([64])
# X 763:	torch.Size([64, 1, 28, 28])
# Y 763:	torch.Size([64])
# X 764:	torch.Size([64, 1, 28, 28])
# Y 764:	torch.Size([64])
# X 765:	torch.Size([64, 1, 28, 28])
# Y 765:	torch.Size([64])
# X 766:	torch.Size([64, 1, 28, 28])
# Y 766:	torch.Size([64])
# X 767:	torch.Size([64, 1, 28, 28])
# Y 767:	torch.Size([64])
# X 768:	torch.Size([64, 1, 28, 28])
# Y 768:	torch.Size([64])
# X 769:	torch.Size([64, 1, 28, 28])
# Y 769:	torch.Size([64])
# X 770:	torch.Size([64, 1, 28, 28])
# Y 770:	torch.Size([64])
# X 771:	torch.Size([64, 1, 28, 28])
# Y 771:	torch.Size([64])
# X 772:	torch.Size([64, 1, 28, 28])
# Y 772:	torch.Size([64])
# X 773:	torch.Size([64, 1, 28, 28])
# Y 773:	torch.Size([64])
# X 774:	torch.Size([64, 1, 28, 28])
# Y 774:	torch.Size([64])
# X 775:	torch.Size([64, 1, 28, 28])
# Y 775:	torch.Size([64])
# X 776:	torch.Size([64, 1, 28, 28])
# Y 776:	torch.Size([64])
# X 777:	torch.Size([64, 1, 28, 28])
# Y 777:	torch.Size([64])
# X 778:	torch.Size([64, 1, 28, 28])
# Y 778:	torch.Size([64])
# X 779:	torch.Size([64, 1, 28, 28])
# Y 779:	torch.Size([64])
# X 780:	torch.Size([64, 1, 28, 28])
# Y 780:	torch.Size([64])
# X 781:	torch.Size([64, 1, 28, 28])
# Y 781:	torch.Size([64])
# X 782:	torch.Size([64, 1, 28, 28])
# Y 782:	torch.Size([64])
# X 783:	torch.Size([64, 1, 28, 28])
# Y 783:	torch.Size([64])
# X 784:	torch.Size([64, 1, 28, 28])
# Y 784:	torch.Size([64])
# X 785:	torch.Size([64, 1, 28, 28])
# Y 785:	torch.Size([64])
# X 786:	torch.Size([64, 1, 28, 28])
# Y 786:	torch.Size([64])
# X 787:	torch.Size([64, 1, 28, 28])
# Y 787:	torch.Size([64])
# X 788:	torch.Size([64, 1, 28, 28])
# Y 788:	torch.Size([64])
# X 789:	torch.Size([64, 1, 28, 28])
# Y 789:	torch.Size([64])
# X 790:	torch.Size([64, 1, 28, 28])
# Y 790:	torch.Size([64])
# X 791:	torch.Size([64, 1, 28, 28])
# Y 791:	torch.Size([64])
# X 792:	torch.Size([64, 1, 28, 28])
# Y 792:	torch.Size([64])
# X 793:	torch.Size([64, 1, 28, 28])
# Y 793:	torch.Size([64])
# X 794:	torch.Size([64, 1, 28, 28])
# Y 794:	torch.Size([64])
# X 795:	torch.Size([64, 1, 28, 28])
# Y 795:	torch.Size([64])
# X 796:	torch.Size([64, 1, 28, 28])
# Y 796:	torch.Size([64])
# X 797:	torch.Size([64, 1, 28, 28])
# Y 797:	torch.Size([64])
# X 798:	torch.Size([64, 1, 28, 28])
# Y 798:	torch.Size([64])
# X 799:	torch.Size([64, 1, 28, 28])
# Y 799:	torch.Size([64])
# X 800:	torch.Size([64, 1, 28, 28])
# Y 800:	torch.Size([64])
# X 801:	torch.Size([64, 1, 28, 28])
# Y 801:	torch.Size([64])
# X 802:	torch.Size([64, 1, 28, 28])
# Y 802:	torch.Size([64])
# X 803:	torch.Size([64, 1, 28, 28])
# Y 803:	torch.Size([64])
# X 804:	torch.Size([64, 1, 28, 28])
# Y 804:	torch.Size([64])
# X 805:	torch.Size([64, 1, 28, 28])
# Y 805:	torch.Size([64])
# X 806:	torch.Size([64, 1, 28, 28])
# Y 806:	torch.Size([64])
# X 807:	torch.Size([64, 1, 28, 28])
# Y 807:	torch.Size([64])
# X 808:	torch.Size([64, 1, 28, 28])
# Y 808:	torch.Size([64])
# X 809:	torch.Size([64, 1, 28, 28])
# Y 809:	torch.Size([64])
# X 810:	torch.Size([64, 1, 28, 28])
# Y 810:	torch.Size([64])
# X 811:	torch.Size([64, 1, 28, 28])
# Y 811:	torch.Size([64])
# X 812:	torch.Size([64, 1, 28, 28])
# Y 812:	torch.Size([64])
# X 813:	torch.Size([64, 1, 28, 28])
# Y 813:	torch.Size([64])
# X 814:	torch.Size([64, 1, 28, 28])
# Y 814:	torch.Size([64])
# X 815:	torch.Size([64, 1, 28, 28])
# Y 815:	torch.Size([64])
# X 816:	torch.Size([64, 1, 28, 28])
# Y 816:	torch.Size([64])
# X 817:	torch.Size([64, 1, 28, 28])
# Y 817:	torch.Size([64])
# X 818:	torch.Size([64, 1, 28, 28])
# Y 818:	torch.Size([64])
# X 819:	torch.Size([64, 1, 28, 28])
# Y 819:	torch.Size([64])
# X 820:	torch.Size([64, 1, 28, 28])
# Y 820:	torch.Size([64])
# X 821:	torch.Size([64, 1, 28, 28])
# Y 821:	torch.Size([64])
# X 822:	torch.Size([64, 1, 28, 28])
# Y 822:	torch.Size([64])
# X 823:	torch.Size([64, 1, 28, 28])
# Y 823:	torch.Size([64])
# X 824:	torch.Size([64, 1, 28, 28])
# Y 824:	torch.Size([64])
# X 825:	torch.Size([64, 1, 28, 28])
# Y 825:	torch.Size([64])
# X 826:	torch.Size([64, 1, 28, 28])
# Y 826:	torch.Size([64])
# X 827:	torch.Size([64, 1, 28, 28])
# Y 827:	torch.Size([64])
# X 828:	torch.Size([64, 1, 28, 28])
# Y 828:	torch.Size([64])
# X 829:	torch.Size([64, 1, 28, 28])
# Y 829:	torch.Size([64])
# X 830:	torch.Size([64, 1, 28, 28])
# Y 830:	torch.Size([64])
# X 831:	torch.Size([64, 1, 28, 28])
# Y 831:	torch.Size([64])
# X 832:	torch.Size([64, 1, 28, 28])
# Y 832:	torch.Size([64])
# X 833:	torch.Size([64, 1, 28, 28])
# Y 833:	torch.Size([64])
# X 834:	torch.Size([64, 1, 28, 28])
# Y 834:	torch.Size([64])
# X 835:	torch.Size([64, 1, 28, 28])
# Y 835:	torch.Size([64])
# X 836:	torch.Size([64, 1, 28, 28])
# Y 836:	torch.Size([64])
# X 837:	torch.Size([64, 1, 28, 28])
# Y 837:	torch.Size([64])
# X 838:	torch.Size([64, 1, 28, 28])
# Y 838:	torch.Size([64])
# X 839:	torch.Size([64, 1, 28, 28])
# Y 839:	torch.Size([64])
# X 840:	torch.Size([64, 1, 28, 28])
# Y 840:	torch.Size([64])
# X 841:	torch.Size([64, 1, 28, 28])
# Y 841:	torch.Size([64])
# X 842:	torch.Size([64, 1, 28, 28])
# Y 842:	torch.Size([64])
# X 843:	torch.Size([64, 1, 28, 28])
# Y 843:	torch.Size([64])
# X 844:	torch.Size([64, 1, 28, 28])
# Y 844:	torch.Size([64])
# X 845:	torch.Size([64, 1, 28, 28])
# Y 845:	torch.Size([64])
# X 846:	torch.Size([64, 1, 28, 28])
# Y 846:	torch.Size([64])
# X 847:	torch.Size([64, 1, 28, 28])
# Y 847:	torch.Size([64])
# X 848:	torch.Size([64, 1, 28, 28])
# Y 848:	torch.Size([64])
# X 849:	torch.Size([64, 1, 28, 28])
# Y 849:	torch.Size([64])
# X 850:	torch.Size([64, 1, 28, 28])
# Y 850:	torch.Size([64])
# X 851:	torch.Size([64, 1, 28, 28])
# Y 851:	torch.Size([64])
# X 852:	torch.Size([64, 1, 28, 28])
# Y 852:	torch.Size([64])
# X 853:	torch.Size([64, 1, 28, 28])
# Y 853:	torch.Size([64])
# X 854:	torch.Size([64, 1, 28, 28])
# Y 854:	torch.Size([64])
# X 855:	torch.Size([64, 1, 28, 28])
# Y 855:	torch.Size([64])
# X 856:	torch.Size([64, 1, 28, 28])
# Y 856:	torch.Size([64])
# X 857:	torch.Size([64, 1, 28, 28])
# Y 857:	torch.Size([64])
# X 858:	torch.Size([64, 1, 28, 28])
# Y 858:	torch.Size([64])
# X 859:	torch.Size([64, 1, 28, 28])
# Y 859:	torch.Size([64])
# X 860:	torch.Size([64, 1, 28, 28])
# Y 860:	torch.Size([64])
# X 861:	torch.Size([64, 1, 28, 28])
# Y 861:	torch.Size([64])
# X 862:	torch.Size([64, 1, 28, 28])
# Y 862:	torch.Size([64])
# X 863:	torch.Size([64, 1, 28, 28])
# Y 863:	torch.Size([64])
# X 864:	torch.Size([64, 1, 28, 28])
# Y 864:	torch.Size([64])
# X 865:	torch.Size([64, 1, 28, 28])
# Y 865:	torch.Size([64])
# X 866:	torch.Size([64, 1, 28, 28])
# Y 866:	torch.Size([64])
# X 867:	torch.Size([64, 1, 28, 28])
# Y 867:	torch.Size([64])
# X 868:	torch.Size([64, 1, 28, 28])
# Y 868:	torch.Size([64])
# X 869:	torch.Size([64, 1, 28, 28])
# Y 869:	torch.Size([64])
# X 870:	torch.Size([64, 1, 28, 28])
# Y 870:	torch.Size([64])
# X 871:	torch.Size([64, 1, 28, 28])
# Y 871:	torch.Size([64])
# X 872:	torch.Size([64, 1, 28, 28])
# Y 872:	torch.Size([64])
# X 873:	torch.Size([64, 1, 28, 28])
# Y 873:	torch.Size([64])
# X 874:	torch.Size([64, 1, 28, 28])
# Y 874:	torch.Size([64])
# X 875:	torch.Size([64, 1, 28, 28])
# Y 875:	torch.Size([64])
# X 876:	torch.Size([64, 1, 28, 28])
# Y 876:	torch.Size([64])
# X 877:	torch.Size([64, 1, 28, 28])
# Y 877:	torch.Size([64])
# X 878:	torch.Size([64, 1, 28, 28])
# Y 878:	torch.Size([64])
# X 879:	torch.Size([64, 1, 28, 28])
# Y 879:	torch.Size([64])
# X 880:	torch.Size([64, 1, 28, 28])
# Y 880:	torch.Size([64])
# X 881:	torch.Size([64, 1, 28, 28])
# Y 881:	torch.Size([64])
# X 882:	torch.Size([64, 1, 28, 28])
# Y 882:	torch.Size([64])
# X 883:	torch.Size([64, 1, 28, 28])
# Y 883:	torch.Size([64])
# X 884:	torch.Size([64, 1, 28, 28])
# Y 884:	torch.Size([64])
# X 885:	torch.Size([64, 1, 28, 28])
# Y 885:	torch.Size([64])
# X 886:	torch.Size([64, 1, 28, 28])
# Y 886:	torch.Size([64])
# X 887:	torch.Size([64, 1, 28, 28])
# Y 887:	torch.Size([64])
# X 888:	torch.Size([64, 1, 28, 28])
# Y 888:	torch.Size([64])
# X 889:	torch.Size([64, 1, 28, 28])
# Y 889:	torch.Size([64])
# X 890:	torch.Size([64, 1, 28, 28])
# Y 890:	torch.Size([64])
# X 891:	torch.Size([64, 1, 28, 28])
# Y 891:	torch.Size([64])
# X 892:	torch.Size([64, 1, 28, 28])
# Y 892:	torch.Size([64])
# X 893:	torch.Size([64, 1, 28, 28])
# Y 893:	torch.Size([64])
# X 894:	torch.Size([64, 1, 28, 28])
# Y 894:	torch.Size([64])
# X 895:	torch.Size([64, 1, 28, 28])
# Y 895:	torch.Size([64])
# X 896:	torch.Size([64, 1, 28, 28])
# Y 896:	torch.Size([64])
# X 897:	torch.Size([64, 1, 28, 28])
# Y 897:	torch.Size([64])
# X 898:	torch.Size([64, 1, 28, 28])
# Y 898:	torch.Size([64])
# X 899:	torch.Size([64, 1, 28, 28])
# Y 899:	torch.Size([64])
# X 900:	torch.Size([64, 1, 28, 28])
# Y 900:	torch.Size([64])
# X 901:	torch.Size([64, 1, 28, 28])
# Y 901:	torch.Size([64])
# X 902:	torch.Size([64, 1, 28, 28])
# Y 902:	torch.Size([64])
# X 903:	torch.Size([64, 1, 28, 28])
# Y 903:	torch.Size([64])
# X 904:	torch.Size([64, 1, 28, 28])
# Y 904:	torch.Size([64])
# X 905:	torch.Size([64, 1, 28, 28])
# Y 905:	torch.Size([64])
# X 906:	torch.Size([64, 1, 28, 28])
# Y 906:	torch.Size([64])
# X 907:	torch.Size([64, 1, 28, 28])
# Y 907:	torch.Size([64])
# X 908:	torch.Size([64, 1, 28, 28])
# Y 908:	torch.Size([64])
# X 909:	torch.Size([64, 1, 28, 28])
# Y 909:	torch.Size([64])
# X 910:	torch.Size([64, 1, 28, 28])
# Y 910:	torch.Size([64])
# X 911:	torch.Size([64, 1, 28, 28])
# Y 911:	torch.Size([64])
# X 912:	torch.Size([64, 1, 28, 28])
# Y 912:	torch.Size([64])
# X 913:	torch.Size([64, 1, 28, 28])
# Y 913:	torch.Size([64])
# X 914:	torch.Size([64, 1, 28, 28])
# Y 914:	torch.Size([64])
# X 915:	torch.Size([64, 1, 28, 28])
# Y 915:	torch.Size([64])
# X 916:	torch.Size([64, 1, 28, 28])
# Y 916:	torch.Size([64])
# X 917:	torch.Size([64, 1, 28, 28])
# Y 917:	torch.Size([64])
# X 918:	torch.Size([64, 1, 28, 28])
# Y 918:	torch.Size([64])
# X 919:	torch.Size([64, 1, 28, 28])
# Y 919:	torch.Size([64])
# X 920:	torch.Size([64, 1, 28, 28])
# Y 920:	torch.Size([64])
# X 921:	torch.Size([64, 1, 28, 28])
# Y 921:	torch.Size([64])
# X 922:	torch.Size([64, 1, 28, 28])
# Y 922:	torch.Size([64])
# X 923:	torch.Size([64, 1, 28, 28])
# Y 923:	torch.Size([64])
# X 924:	torch.Size([64, 1, 28, 28])
# Y 924:	torch.Size([64])
# X 925:	torch.Size([64, 1, 28, 28])
# Y 925:	torch.Size([64])
# X 926:	torch.Size([64, 1, 28, 28])
# Y 926:	torch.Size([64])
# X 927:	torch.Size([64, 1, 28, 28])
# Y 927:	torch.Size([64])
# X 928:	torch.Size([64, 1, 28, 28])
# Y 928:	torch.Size([64])
# X 929:	torch.Size([64, 1, 28, 28])
# Y 929:	torch.Size([64])
# X 930:	torch.Size([64, 1, 28, 28])
# Y 930:	torch.Size([64])
# X 931:	torch.Size([64, 1, 28, 28])
# Y 931:	torch.Size([64])
# X 932:	torch.Size([64, 1, 28, 28])
# Y 932:	torch.Size([64])
# X 933:	torch.Size([64, 1, 28, 28])
# Y 933:	torch.Size([64])
# X 934:	torch.Size([64, 1, 28, 28])
# Y 934:	torch.Size([64])
# X 935:	torch.Size([64, 1, 28, 28])
# Y 935:	torch.Size([64])
# X 936:	torch.Size([64, 1, 28, 28])
# Y 936:	torch.Size([64])
# X 937:	torch.Size([32, 1, 28, 28])
# Y 937:	torch.Size([32])

# %% [markdown]
# Once you've printed the whole loop and the shape of the matrices your are plugging into the model, everything seems to be clear enough. In a cell shown above, we figured out the number of samples the training dataset contains: 60000 pictures.
# 60000 / 64 = 937 batches of 64 samples and a last batch with 32 samples
#
# So the training loop will run <strong>937 times</strong> loading <strong>64 samples</strong> of the training dataset and a last time with 1 batch of 32 samples

# %% [markdown]
# #### Define the Test Function
#
# Once we've defined our training function we can test our model to check out if the model can predict what type of clothing we have in every single sample of the test dataset

# %% [markdown]
# <strong>Exercise 13</strong>: Print the number of samples included in the test dataset

# %%
### Your code starts here ###

dataset_len = len(test_dataloader)

### Your code ends here ###

print("The number of samples included in the test dataset is: {0:d}".format(dataset_len))
# Out:
# The number of samples included in the test dataset is: 157

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    
    avg_loss = test_loss / num_batches
    
    accuracy = (correct / size) * 100
    
    print("Test Error: \n Accuracy: {0:.2f} %, Average loss: {1:.6f}".format(accuracy,avg_loss))

# %% [markdown]
# ### Putting all together

# %% [markdown]
# Everything is ready to go. Now we can run train and test functions. Let's run the machine

# %%
epochs = 5
for t in range(epochs):
    print(f"\nEpoch {t+1}\n-------------------------------")
    train(train_dataloader, my_other_model, loss_fn, optimizer)
    test(test_dataloader, my_other_model, loss_fn)
print("\nTraining done!")
# Out:
# Epoch 1
# -------------------------------
# Loss with batch nº 1: 2.303206
# Loss with batch nº 101: 2.299020
# Loss with batch nº 201: 2.295419
# Loss with batch nº 301: 2.296020
# Loss with batch nº 401: 2.297590
# Loss with batch nº 501: 2.295607
# Loss with batch nº 601: 2.297667
# Loss with batch nº 701: 2.293998
# Loss with batch nº 801: 2.295647
# Loss with batch nº 901: 2.299297
# Test Error:
#  Accuracy: 24.66 %, Average loss: 2.291044
#
# Epoch 2
# -------------------------------
# Loss with batch nº 1: 2.292382
# Loss with batch nº 101: 2.285187
# Loss with batch nº 201: 2.278372
# Loss with batch nº 301: 2.285895
# Loss with batch nº 401: 2.279662
# Loss with batch nº 501: 2.279944
# Loss with batch nº 601: 2.286403
# Loss with batch nº 701: 2.277015
# Loss with batch nº 801: 2.283095
# Loss with batch nº 901: 2.288211
# Test Error:
#  Accuracy: 28.98 %, Average loss: 2.274765
#
# Epoch 3
# -------------------------------
# Loss with batch nº 1: 2.274773
# Loss with batch nº 101: 2.263689
# Loss with batch nº 201: 2.251778
# Loss with batch nº 301: 2.269423
# Loss with batch nº 401: 2.252913
# Loss with batch nº 501: 2.255223
# Loss with batch nº 601: 2.268775
# Loss with batch nº 701: 2.250035
# Loss with batch nº 801: 2.262799
# Loss with batch nº 901: 2.272655
# Test Error:
#  Accuracy: 26.92 %, Average loss: 2.249111
#
# Epoch 4
# -------------------------------
# Loss with batch nº 1: 2.247529
# Loss with batch nº 101: 2.227936
# Loss with batch nº 201: 2.207561
# Loss with batch nº 301: 2.241115
# Loss with batch nº 401: 2.208701
# Loss with batch nº 501: 2.213728
# Loss with batch nº 601: 2.239296
# Loss with batch nº 701: 2.204618
# Loss with batch nº 801: 2.232035
# Loss with batch nº 901: 2.247034
# Test Error:
#  Accuracy: 24.65 %, Average loss: 2.205810
#
# Epoch 5
# -------------------------------
# Loss with batch nº 1: 2.203805
# Loss with batch nº 101: 2.167454
# Loss with batch nº 201: 2.133089
# Loss with batch nº 301: 2.193651
# Loss with batch nº 401: 2.133596
# Loss with batch nº 501: 2.144342
# Loss with batch nº 601: 2.191259
# Loss with batch nº 701: 2.131520
# Loss with batch nº 801: 2.187055
# Loss with batch nº 901: 2.210197
# Test Error:
#  Accuracy: 24.94 %, Average loss: 2.140568
#
# Training done!

# %% [markdown]
# ### Saving the Pytorch model

# %% [markdown]
# You can reuse your trained model whenever you want. To do that, you have to save it first

# %%
torch.save(my_other_model.state_dict(), "model.pth")
print("Saved PyTorch Model State to model.pth")
# Out:
# Saved PyTorch Model State to model.pth

# %% [markdown]
# ### Loading a saved Pytorch model
#
# You can use your saved model for further predictions. For this purpose, please load it first.

# %%
model = MyNeuralNetwork2()
model.load_state_dict(torch.load("model.pth"))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### Predicting type of outfit
#
# Now you can use your model to predict wich of the outfit included in the experiment is present in your picture. Next function gives you the ability to use the model to do so

# %%
def outfit_predictor(outfit,model):
    classes = [
        "T-shirt/top",
        "Trouser",
        "Pullover",
        "Dress",
        "Coat",
        "Sandal",
        "Shirt",
        "Sneaker",
        "Bag",
        "Ankle boot"
        ]
    x, y = outfit[0], outfit[1] 
    model.eval()
    with torch.no_grad():
        pred = model(x)
        predicted, actual = classes[pred[0].argmax(0)], classes[y]
        return predicted,actual

# %% [markdown]
# <strong>Exercise 14</strong>: Choose any picture of the dataset and test if the model predicts what type of outfit it is. For example the picture number 7001

# %%
### Your code starts here ###

pic_num = 390
picture = test_data[pic_num]
predicted, actual = outfit_predictor(picture,model)

plt.imshow(picture[0].permute(1,2,0),cmap="gray")
### Your code ends here ###

print("Predicted: {0:s}, Actual: {1:s}".format(predicted,actual))
# Out:
# Predicted: Bag, Actual: Shirt

# %% [markdown]
# As final drill, let's make a photo to any outfit you have available just now and check if the model is able to predict what it is. The next function takes the picture and predicts what it is.

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt 

def outfit_predict_from_image(url,model):

    classes = [
            "T-shirt/top",
            "Trouser",
            "Pullover",
            "Dress",
            "Coat",
            "Sandal",
            "Shirt",
            "Sneaker",
            "Bag",
            "Ankle boot"
            ]
    # Converting to gray-scale picture (just one matrix instead of three RGB matrices)
    img = Image.open(url).convert('L')

    # Resizing to (28,28
    image = np.array(img.resize((28, 28)))/255

    # Adding one dimension to fit the shape Pytorch expects
    image = image.reshape(1,28,28)

    # Converting to Torch tensor
    torch_image = torch.from_numpy(image)

    # Flattening the 28,28 matrix (check the model architecture) and converting to float number type
    torch_image = torch_image.reshape(1,28*28).float()

    # Predicting
    with torch.no_grad():
        pred = model(torch_image)
    
    # Matching the prediction with the type of outfit
    predicted = classes[pred[0].argmax(0)]

    return(predicted,image)

# %% [markdown]
# <strong>Exercise 15</strong>: Use the function coded below to predict the outfit you've just made a picture of.

# %%
### Your code starts here ###

outfit_prediction, image = outfit_predict_from_image("./dress.jpeg",model)

### Your code ends here ###

print('The machine has predicted that your picture is a {0:s}.'.format(outfit_prediction))
plt.imshow(np.transpose(image,(1,2,0)),cmap="gray")
# Out:
# The machine has predicted that your picture is a Bag.

# %%
plt.imshow(image.reshape(28,28),cmap='gray',vmin=0,vmax=1)

# %% [markdown]
# <strong>Exercise 16</strong>: Try to improve the Accuracy of your model. What should you do? Wich of all parameters shown above should you modify?

# %%
class MyNeuralNetwork3(nn.Module):
    def __init__(self):
        super().__init__()
        self.Conv1 = nn.Conv2d(1, 32, 3, 1)
        self.flatten = nn.Flatten()
        self.Linear1 = nn.Linear(32 * 26 * 26, 1024)
        self.Linear2 = nn.Linear(1024, 512)
        self.Linear3 = nn.Linear(512, 256)
        self.Linear4 = nn.Linear(256, 128)
        self.Linear5 = nn.Linear(128, 10)
    
    def forward(self, input):
        x = F.relu(self.Conv1(input))
        x = self.flatten(x)
        x = F.relu(self.Linear1(x))
        x = F.relu(self.Linear2(x))
        x = F.relu(self.Linear3(x)) 
        x = F.relu(self.Linear4(x)) 
        output = F.relu(self.Linear5(x)) 
        return output





new_model = MyNeuralNetwork3().to(device)
new_loss_fn = nn.CrossEntropyLoss()
new_optimizer = torch.optim.Adam(new_model.parameters(),lr=1e-3)

epochs = 1
for t in range(epochs):
    print(f"\nEpoch {t+1}\n-------------------------------")
    train(train_dataloader, new_model, new_loss_fn, new_optimizer)
    test(test_dataloader, new_model, new_loss_fn)
print("\nTraining done!")
# Out:
# Epoch 1
# -------------------------------
# Loss with batch nº 1: 2.303058
# Loss with batch nº 101: 1.495165
# Loss with batch nº 201: 1.355226
# Loss with batch nº 301: 1.443399
# Loss with batch nº 401: 1.246035
# Loss with batch nº 501: 1.332730
# Loss with batch nº 601: 0.773960
# Loss with batch nº 701: 0.903757
# Loss with batch nº 801: 1.038979
# Loss with batch nº 901: 0.934897
# Test Error:
#  Accuracy: 61.21 %, Average loss: 0.996321
#
# Training done!

# %%
ModelSafeName = "new_model"
ModelSafeType = ".pth"
Version = 1
ModelSafeNameFinal =f"{ModelSafeName}({Version}){ModelSafeType}"
while os.path.exists(ModelSafeNameFinal):
    Version +=1
    ModelSafeNameFinal =f"{ModelSafeName}({Version}){ModelSafeType}"
#torch.save(new_model.state_dict(), ModelSafeNameFinal)
print(f"Saved PyTorch Model State to {ModelSafeNameFinal}")
print(f"With and accuracy of 89.3% and an average loss of 0.37")
# Out:
# Saved PyTorch Model State to new_model(3).pth
# With and accuracy of 89.3% and an average loss of 0.37

# %%
class MyNeuralNetwork4(nn.Module):
    def __init__(self):
        super().__init__()
        self.Conv1 = nn.Conv2d(1, 32, 3, 1)
        self.flatten = nn.Flatten()
        self.Linear1 = nn.Linear(32 * 26 * 26, 1024)
        self.Linear2 = nn.Linear(1024, 512)
        self.Linear3 = nn.Linear(512, 256)
        self.Linear4 = nn.Linear(256, 128)
        self.Linear5 = nn.Linear(128, 10)
    
    def forward(self, input):
        x = F.relu(self.Conv1(input))
        x = self.flatten(x)
        x = F.relu(self.Linear1(x))
        x = F.relu(self.Linear2(x))
        x = F.relu(self.Linear3(x)) 
        x = F.relu(self.Linear4(x)) 
        output = F.relu(self.Linear5(x)) 
        return output

# %%
modelFinal = MyNeuralNetwork4()
modelFinal.load_state_dict(torch.load("new_model(2).pth"))
print(modelFinal)
# Out:
# MyNeuralNetwork4(
#   (Conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (Linear1): Linear(in_features=21632, out_features=1024, bias=True)
#   (Linear2): Linear(in_features=1024, out_features=512, bias=True)
#   (Linear3): Linear(in_features=512, out_features=256, bias=True)
#   (Linear4): Linear(in_features=256, out_features=128, bias=True)
#   (Linear5): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
### Your code starts here ###

pic_num = 0
picture = test_data[pic_num]
predicted, actual = outfit_predictor(picture,new_model)

plt.imshow(picture[0].permute(1,2,0),cmap="gray")
### Your code ends here ###

print("Predicted: {0:s}, Actual: {1:s}".format(predicted,actual))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5780\2084033402.py in <module>
#       3 pic_num = 0
#       4 picture = test_data[pic_num]
# ----> 5 predicted, actual = outfit_predictor(picture,new_model)
#       6
#       7 plt.imshow(picture[0].permute(1,2,0),cmap="gray")
#
# ~\AppData\Local\Temp\ipykernel_5780\2402430709.py in outfit_predictor(outfit, model)
#      15     model.eval()
#      16     with torch.no_grad():
# ---> 17         pred = model(x)
#      18         predicted, actual = classes[pred[0].argmax(0)], classes[y]
#      19         return predicted,actual
#
# c:\Users\Nico\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\AppData\Local\Temp\ipykernel_5780\3169119952.py in forward(self, input)
#      13         x = F.relu(self.Conv1(input))
#      14         x = self.flatten(x)
# ---> 15         x = F.relu(self.Linear1(x))
#      16         x = F.relu(self.Linear2(x))
#      17         x = F.relu(self.Linear3(x))
#
# c:\Users\Nico\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\Users\Nico\Anaconda3\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (32x676 and 21632x1024)
